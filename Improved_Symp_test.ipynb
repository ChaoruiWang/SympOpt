# %% [markdown]
# # Reference
#
# The original code can be found https://github.com/Lezcano/expRNN
#
# This pythonnotebook concentrates on the implementation of improved dynamic trivialization method over symplectic group.

# %%
import torch
import torch.nn as nn
import numpy as np
import argparse
from torchvision import datasets, transforms
from torch.functional import F

import matplotlib.pyplot as plt
import math

import sys
sys.argv=['']
del sys

# %% [markdown]
# # Notations
# To be consistent with the thesis paper, in the following context, let's denote:
#
# (1). $G = Sp(2n, \mathbb R) = \{A: A^TJA = J\}$, the symplectic group.
#
# (2). $A \in G$, a symplectic matrix.
#
# (3). $X \in \mathfrak{g} = sp(2n,\mathbb{R}) = \{X: (XJ)^T=(XJ)\}$, a matrix in the Lie algebra of $G$.
#
# (4). $Y \in T_AG$, a matrix in the tangent space at $A$.
#
# $A$ and $X$ will be used most of the time.

# %% [markdown]
# #Parameters
# Under dynamic trivialization, in a general Neural Network combining Symplectic layers and Euclidean layers, we have two kinds of parameters.
#
# (1). The matrices $X$ in the Lie algebra $\mathfrak{g} \cong T_{e}G$ of the Symplectic layers.
#
# (2). The parameters $w$ of regular Euclidean layers.
#
# In the following codes, the writer Lezcano denotes
#
# (1). symplectic Lie algebra matrix $X$ with 'parametrized_params' and
#
# (2). regular Euclidean parameters $w$ with 'unconstrained_params'.
#
# If we simply want to test the optimization on symplectic group, we shall just use the 'LinearSymplectic' layer (find it below) to build up the test, i.e. we will only have the first kind of parameters $X$.

# %%
def get_parameters(model):
    parametrized_params = []

    def get_parametrized_params(mod):
        nonlocal parametrized_params
        if isinstance(mod, ParametrizationImproved):
            parametrized_params.append(mod.X)

    def not_in(elem, l):
        return all(elem is not x for x in l)

    model.apply(get_parametrized_params)

    unconstrained_params = (param for param in model.parameters() if not_in(param, parametrized_params))

    return unconstrained_params, parametrized_params

# %% [markdown]
# #Modified Parametrization Class
#
# The following build-up of ParametrizationImproved class makes some modifications to Lezcano's original code.
#
# The main differences are that it must be dynamic trivialization and the K must be some integer between $[1,\infty)$. And it checks whether we are moving in the diffeomorphism region. If not, it will immediatetly stop gradient descent and change the base point using previous point in the tangent space that is still in the diffeomorphism region.

# %%
# Parametrization Class

class ParametrizationImproved(nn.Module):
    """
    Implements the parametrization of a manifold in terms of a Euclidean space
    It gives the parametrized matrix through the attribute `A`
    """

    def __init__(self, X, base, K):
        super(ParametrizationImproved, self).__init__()
        self.X = nn.Parameter(X)
        # To see whether the X is in the diffeomorphism region
        # It is useful to check when the X is moving out of the diffeomorphism region 
        # so that one can change the value of K and the learning rate properly.
        self.is_diffeo = None

        # This is necessary, as it will be generated again the first time that self.A is called
        # We still need to register the buffer though
        self.register_buffer("_A", None)
        self.register_buffer('base', base)

        self.k = 0
        self.K = K

        #record the X before gradient descent, useful when moving out of the diffeo region.
        self.X_memo = None  

        # This implements the parametrization trick in a rather slick way.
        # We put a hook on X, such that, whenever its gradients are computed, we
        # get rid of self._A so that it has to be recomputed the next time that
        # self.A is accessed. Also we record the previous point in the tangent space
        # for use if we are moving out of the diffeo region.
        def hook(grad):
            nonlocal self
            self._A = None
            self.X_memo = torch.clone(self.X)
        self.X.register_hook(hook)

    #change the base point
    def rebase(self):
        with torch.no_grad():
            self.base.data.copy_(self._A.data)
            self.X.data.zero_()

    @property
    def A(self):
        not_A = self._A is None
        self.is_diffeo = self.check_diffeo(self.X)
        if not_A or (not self._A.grad_fn and torch.is_grad_enabled()):
            # If X is not in the diffeo region, change the base point immediately.
            # Notice that there can be the situation that the base stops changing from some point.
            # The reason may be that X moves out of diffeo region with only one gradient descent
            # which makes the base get stuck.
            # One should check the value of self.is_diffeo and try some other K or use smaller learning rates.
            if not self.is_diffeo:
                self._A = self.retraction(self.X_memo, self.base)
                # Just to be safe
                self._A.requires_grad_()
                # Now self._A it's not a leaf tensor, so we convert it into a leaf
                self._A.retain_grad()
                self.rebase()
            else:
                self._A = self.retraction(self.X, self.base)
                # Just to be safe
                self._A.requires_grad_()
                # Now self._A it's not a leaf tensor, so we convert it into a leaf
                self._A.retain_grad()
                if not_A:
                    # Change the basis after K optimization steps
                    if self.k == 0:
                        self.rebase()
                    # Increment the counter afterwards as we change the basis in the first iteration 
                    self.k = (self.k + 1) % self.K
        return self._A


    def check_diffeo(self, X):
        '''
        This method check whether X is in the diffeomorphism region.
        It return Ture if it is, otherwise False.
        '''
        raise NotImplementedError


    def retraction(self, X, base):
        """
        It computes r_{base}(X).
        Notice that X will not always be in the tangent space of our manifold
          For this reason, we first have to use X to parametrize the tangent space,
          and then compute the retraction
        When dealing with Lie groups, raw_X is always projected into the Lie algebra, as an optimization (cf. Section E in the paper)
        """
        raise NotImplementedError

    def project(self, base):
        """
        This method is OPTIONAL
        It returns the projected base back into the manifold
        """
        raise NotImplementedError

    def forward(self, input):
        """
        It uses the attribute self.A to implement the layer itself (e.g. Linear, CNN, ...)
        """
        raise NotImplementedError

# %% [markdown]
# #Linear Symplectic Layer
#
# This is a simple Linear Symplectic layer.
#
# Input: vector/matrix $v$.
#
# operateion: left multiplication, i.e. $vA$, where $A \in Sp(2n,\mathbb R)$
#
# output: $vA$
#
# (Notice that the function "forward" can be rewritten to produce any other desired structure. In our simple test of optimization, here we just use a very simple linear structure with no bias.)
#
# As the comment of "retraction" in the above Parametrization class, we would expect $X$ to be in $sp(2n, \mathbb{R}) = \{JX+X^TJ = 0\}$.
#
# Note that for any $Y \in T_AG$,
# \begin{align*}
#     \exp_A: T_A G &\to G\\
#                 Y &\mapsto A\exp(A^{-1}Y)
# \end{align*}
#
# and $T_AG = \{AX: X \in \mathfrak{g}\}$, i.e. $Y = AX$ for some $X \in sp(2n,\mathbb{R})$
#
# Therefore,
# $$\exp_A(Y) = A\exp(A^{-1}Y) = A\exp(A^{-1}AX) = A\exp(X)$$
# for $X \in sp(2n,\mathbb{R})$.
#
# This means that if given A and a parametrization of $sp(2n, \mathbb{R})$, we can calculate the exponential map.
#
# To parametrize $sp(2n,\mathbb{R})$, first notice that
# \begin{align*}
#     sp(2n,\mathbb{R}) &= \{X: JX+X^TJ = 0\}\\
#                       &= \{X: JX-X^TJ^T = 0\}\\
#                       &= \{X: JX-(JX)^T = 0\}\\
#                       &= \{X: JX=(JX)^T\}
# \end{align*}
#
# So we can first make $JX$ into symmetric matrix and then left multiply $J^{-1} = J^T$ to parametrize $X$, and thus do the parametrization.

# %%
#LinearSymplectic

class LinearSymplectic(ParametrizationImproved):
    #input a vector/matrix v, left multiply with symplectic matrix B
    #and output the vector/matrix vB. 
    def __init__(self, size, param, K):
        if size % 2 != 0:
            raise ValueError("Symplectic group is supposed to have size 2n.")
        X = torch.empty(size, size)
        base = torch.empty(size, size)
        super(LinearSymplectic, self).__init__(X, base, K)
        self.size = size
        self.param = param
        self.init_base = nn.init.eye_
        self.init_X = nn.init.zeros_
        self.reset_parameters()

        #set the matrix J of Sp(2n,R)
        n = self.size //2 
        zero = torch.zeros(n,n)
        neg_one = torch.tensor([-1.0 for i in range(n)])
        pos_one = torch.tensor([1.0 for i in range(n)])
        neg_I = torch.diag(neg_one)
        pos_I = torch.diag(pos_one)
        J1 = torch.hstack((zero,pos_I))
        J2 = torch.hstack((neg_I,zero))
        self.J = torch.vstack((J1,J2))

    def reset_parameters(self):
        self.init_X(self.X)
        self.init_base(self.base)
        

    def forward(self, input):
        #this function can be rewritten to produce any other desired structure
        #in our simple test of optimization, here we just use a very simple linear structure with no bias.
        return input.matmul(self.A)


    def retraction(self, X, base):
        '''
        make sure JX is symmetric so that X is in Lie algebra of symplectic group.
        The retraction map is not unique. Any parametrization that makes X in the the Lie algebra can work.
        The one below is another retraction for symplectic group.
        '''
        X = (X + X.t())/2
        X = self.J.mm(X)
        A = base.mm(self.param(X)) 
        return A

    '''
    def retraction(self, X, base):
        #make sure JX is symmetric so that X is in Lie algebra of symplectic group.
        #The retraction map is not unique. Any parametrization that makes X in the the Lie algebra can work.
        JX = self.J.mm(X)
        JX = (JX+JX.t())/2
        X = self.J.t().mm(JX)
        A = base.mm(self.param(X))
        return A
    '''

    def check_diffeo(self, X):
        is_diffeo = True
        X = (X + X.t())/2
        X = self.J.mm(X)
        eigenvalues = torch.linalg.eigvals(X)
        for eigenvalue in eigenvalues:
            if eigenvalue.imag >= np.pi:
                is_diffeo = False
        return is_diffeo

# %% [markdown]
# #Trivialization
#
# Here we shall just put emphasis on the expm class.

# %%
# trivializations

def cayley_map(A):
    n = A.size(0)
    Id = torch.eye(n, dtype=X.dtype, device=A.device)
    return torch.solve(Id - A, Id + A)[0]

class expm_class(torch.autograd.Function):
    @staticmethod
    def forward(ctx, X):
        ctx.save_for_backward(X)
        return expm32(X)

    @staticmethod
    def backward(ctx, G):
        (X,) = ctx.saved_tensors
        return differential(expm32, X.t(), G)

expm = expm_class.apply

# %% [markdown]
# # Matrix Exponential and the Differential
#
# 'expm32' calculates the matrix exponential.
#
# 'differential' computes the differential of $f$ at $A$ when acting on $E$: $(df)_A(E)$

# %%
# matrx exponential and differential 

"""
Adaptation of expm and expm_frechet in numpy for torch
"""

#
# Authors: Travis Oliphant, March 2002
#          Anthony Scopatz, August 2012 (Sparse Updates)
#          Jake Vanderplas, August 2012 (Sparse Updates)
#

from __future__ import division, print_function, absolute_import

import math

import numpy as np

import torch
import scipy.special

def _onenorm_matrix_power_nnm(A, p):
    """
    Compute the 1-norm of a non-negative integer power of a non-negative matrix.
    Parameters
    ----------
    A : a square ndarray or matrix or sparse matrix
        Input matrix with non-negative entries.
    p : non-negative integer
        The power to which the matrix is to be raised.
    Returns
    -------
    out : float
        The 1-norm of the matrix power p of A.
    """
    # check input
    if int(p) != p or p < 0:
        raise ValueError('expected non-negative integer p')
    p = int(p)
    if len(A.shape) != 2 or A.shape[0] != A.shape[1]:
        raise ValueError('expected A to be like a square matrix')

    # Explicitly make a column vector so that this works when A is a
    # numpy matrix (in addition to ndarray and sparse matrix).
    v = torch.ones((A.shape[0], 1), dtype=A.dtype, device=A.device)
    M = A.t()
    for _ in range(p):
        v = M.mm(v)
    return torch.max(v).item()


def _onenorm(A):
    return torch.norm(A, 1).item()


def _ident_like(A):
    return torch.eye(A.shape[0], A.shape[1], dtype=A.dtype, device=A.device)

class _ExpmPadeHelper(object):
    """
    Help lazily evaluate a matrix exponential.
    The idea is to not do more work than we need for high expm precision,
    so we lazily compute matrix powers and store or precompute
    other properties of the matrix.
    """
    def __init__(self, A):
        """
        Initialize the object.
        Parameters
        ----------
        A : a dense or sparse square numpy matrix or ndarray
            The matrix to be exponentiated.
        """
        self.A = A
        self._A2 = None
        self._A4 = None
        self._A6 = None
        self._A8 = None
        self._A10 = None
        self._d4_exact = None
        self._d6_exact = None
        self._d8_exact = None
        self._d10_exact = None
        self._d4_approx = None
        self._d6_approx = None
        self._d8_approx = None
        self._d10_approx = None
        self.ident = _ident_like(A)

    @property
    def A2(self):
        if self._A2 is None:
            self._A2 = self.A.mm(self.A)
        return self._A2

    @property
    def A4(self):
        if self._A4 is None:
            self._A4 = self.A2.mm(self.A2)
        return self._A4

    @property
    def A6(self):
        if self._A6 is None:
            self._A6 = self.A4.mm(self.A2)
        return self._A6

    @property
    def A8(self):
        if self._A8 is None:
            self._A8 = self.A6.mm(self.A2)
        return self._A8

    @property
    def A10(self):
        if self._A10 is None:
            self._A10 = self.A4.mm(self.A6)
        return self._A10

    @property
    def d4_tight(self):
        if self._d4_exact is None:
            self._d4_exact = _onenorm(self.A4)**(1/4.)
        return self._d4_exact

    @property
    def d6_tight(self):
        if self._d6_exact is None:
            self._d6_exact = _onenorm(self.A6)**(1/6.)
        return self._d6_exact

    @property
    def d8_tight(self):
        if self._d8_exact is None:
            self._d8_exact = _onenorm(self.A8)**(1/8.)
        return self._d8_exact

    @property
    def d10_tight(self):
        if self._d10_exact is None:
            self._d10_exact = _onenorm(self.A10)**(1/10.)
        return self._d10_exact

    @property
    def d4_loose(self):
        return self.d4_tight

    @property
    def d6_loose(self):
        return self.d6_tight

    @property
    def d8_loose(self):
        return self.d8_tight

    @property
    def d10_loose(self):
        return self.d10_tight

    def pade3(self):
        b = (120., 60., 12., 1.)
        U = self.A.mm(b[3]*self.A2 + b[1]*self.ident)
        V = b[2]*self.A2 + b[0]*self.ident
        return U, V

    def pade5(self):
        b = (30240., 15120., 3360., 420., 30., 1.)
        U = self.A.mm(b[5]*self.A4 + b[3]*self.A2 + b[1]*self.ident)
        V = b[4]*self.A4 + b[2]*self.A2 + b[0]*self.ident
        return U, V

    def pade7_scaled(self, s):
        b = (17297280., 8648640., 1995840., 277200., 25200., 1512., 56., 1.)

        B = self.A * 2**-s
        B2 = self.A2 * 2**(-2*s)
        B4 = self.A4 * 2**(-4*s)
        B6 = self.A6 * 2**(-6*s)

        U = B.mm(b[7]*B6 + b[5]*B4 + b[3]*B2 + b[1]*self.ident)
        V = b[6]*B6 + b[4]*B4 + b[2]*B2 + b[0]*self.ident
        return U, V


def expm32(A):
    """
    Compute the matrix exponential using Pade approximation.
    Parameters
    ----------
    A : (M,M) array_like or sparse matrix
        2D Array or Matrix (sparse or dense) to be exponentiated
    Returns
    -------
    expA : (M,M) ndarray
        Matrix exponential of `A`
    Notes
    -----
    This is algorithm (6.1) which is a simplification of algorithm (5.1).
    .. versionadded:: 0.12.0
    References
    ----------
    .. [1] Awad H. Al-Mohy and Nicholas J. Higham (2009)
           "A New Scaling and Squaring Algorithm for the Matrix Exponential."
           SIAM Journal on Matrix Analysis and Applications.
           31 (3). pp. 970-989. ISSN 1095-7162
    """
    return _expm(A)


def _expm(A):
    # Core of expm, separated to allow testing exact and approximate
    # algorithms.

    # Avoid indiscriminate asarray() to allow sparse or other strange arrays.
    if len(A.shape) != 2 or A.shape[0] != A.shape[1]:
        raise ValueError('expected a square matrix')

    # Trivial case
    if A.shape == (1, 1):
        return torch.exp(A)

    # Track functions of A to help compute the matrix exponential.
    h = _ExpmPadeHelper(A)

    # Try Pade order 3.
    eta_1 = max(h.d4_loose, h.d6_loose)
    theta3 = 4.2587300348979312e-001
    if eta_1 < theta3 and _ell(h.A, 3) == 0:
        U, V = h.pade3()
        return _solve_P_Q(U, V)

    # Try Pade order 5.
    eta_2 = max(h.d4_tight, h.d6_loose)
    theta5 = 1.8801526985337688e+000
    if eta_2 < theta5 and _ell(h.A, 5) == 0:
        U, V = h.pade5()
        return _solve_P_Q(U, V)

    theta_7 = 3.9257248464332842e+000
    eta_3 = max(h.d6_tight, h.d8_loose)
    s = max(int(np.ceil(np.log2(eta_3 / theta_7))), 0)

    s += _ell(2**-s * h.A, 7)
    U, V = h.pade7_scaled(s)
    X = _solve_P_Q(U, V)
    return torch.matrix_power(X, 2**s)


def _solve_P_Q(U, V):
    P = U + V
    Q = -U + V
    return torch.linalg.solve(P, Q)


def _ell(A, m):
    """
    A helper function for expm_2009.
    Parameters
    ----------
    A : linear operator
        A linear operator whose norm of power we care about.
    m : int
        The power of the linear operator
    Returns
    -------
    value : int
        A value related to a bound.
    """
    if len(A.shape) != 2 or A.shape[0] != A.shape[1]:
        raise ValueError('expected A to be like a square matrix')

    p = 2*m + 1

    # The c_i are explained in (2.2) and (2.6) of the 2005 expm paper.
    # They are coefficients of terms of a generating function series expansion.
    choose_2p_p = scipy.special.comb(2*p, p, exact=True)
    abs_c_recip = float(choose_2p_p * math.factorial(2*p + 1))

    # This is explained after Eq. (1.2) of the 2009 expm paper.
    # It is the "unit roundoff" of IEEE double precision arithmetic.
    u = 2.**-24

    # Compute the one-norm of matrix power p of abs(A).
    A_abs_onenorm = _onenorm_matrix_power_nnm(abs(A), p)

    # Treat zero norm as a special case.
    if not A_abs_onenorm:
        return 0

    alpha = A_abs_onenorm / (_onenorm(A) * abs_c_recip)
    return max(int(np.ceil(np.log2(alpha/u) / (2 * m))), 0)

def differential(f, A, E):
    """ Computes the differential of f at A when acting on E:  (df)_A(E) """
    n = A.size(0)
    M = torch.zeros(2*n, 2*n, dtype=A.dtype, device=A.device, requires_grad=False)
    M[:n, :n] = A
    M[n:, n:] = A
    M[:n, n:] = E
    return f(M)[:n, n:]

# %% [markdown]
# # Simple Test(Vanilla)
#
# We first generate a fixed symplectic matrix $G$. Then we generated some random vectors $v$. Through a right multiplication by $G$, we also generate the labels $y = vG$.
#
# Now we feed the generated $v$ and $y$ into the LinearSymplectic layer and train the model. Thus the optimization problem is
# $$
# \min\limits_{A \in Sp(2n,\mathbb{R})}\mathbb{E}[||vA-y||^2]
# $$
# where $||.||$ is the vector norm.
#
# The exact solution should be the G we created, and we expect the result to be close to G.

# %% [markdown]
# ##Defalut setting, K=10, vanilla epoch 3000, batch epoch 300, learning rate 0.05

# %%
# test_main
parser = argparse.ArgumentParser(description='Linear Symplectic Layer Simple Task')
#parser.add_argument('--batch_size', type=int, default=32)
#parser.add_argument('--hidden_size', type=int, default=170)
parser.add_argument('--epochs', type=int, default=3000)
parser.add_argument('--epochs2', type=int, default=300)
#parser.add_argument('--lr', type=float, default=1e-2)
parser.add_argument('--lr_symp', type=float, default=5e-2)
parser.add_argument("--permute", action="store_true")
parser.add_argument('--K', type=str, default="10", help='The K parameter in the dtriv algorithm. It should be a positive integer.')


args = parser.parse_args()

#batch_size  = args.batch_size
#hidden_size = args.hidden_size
epochs      = args.epochs
epochs2     = args.epochs2
device      = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
args.K      = int(args.K)

# %% [markdown]
# ## Data

# %%
input_size = 4
np.random.seed(0)

G = [[ 1.,   3.,   1.,   0. ],
     [ 2.,   4., -2.5,  1.5],
     [ 0.,   0.,  -2.,   1. ],
     [ 0.,   0.,   1.5, -0.5]]

n = 1000

V = []
y = []
for i in range(n):
    v = np.random.rand(4) # change to random vector
    V.append(v)
    y.append(v.dot(G) )

# %% [markdown]
# ##Test Model 1, K=10, learning rate=0.005

# %%
losses_1 = []

class test_Model(nn.Module):
    def __init__(self, input_size):
        super(test_Model, self).__init__()
        self.symp = LinearSymplectic(input_size, param=expm, K=args.K)
        self.loss_func = nn.MSELoss()

    def forward(self, input): 
        l = self.symp(input)
        return l

    def loss(self, preds, y):
        return self.loss_func(preds, y)

def main():
    model = test_Model(input_size).to(device)
    model.train()
    non_symp_params, log_symp_params = get_parameters(model)
    #optim = torch.optim.Adam(non_symp_params, args.lr)
    optim_symp = torch.optim.Adam(log_symp_params, lr=5e-3)

    for epoch in range(10000):
        preds = model(torch.tensor(V).float())
        loss = model.loss(preds, torch.tensor(y).float())
        loss.backward()
        #if optim.step():
            #optim.step()
        if optim_symp:
            optim_symp.step()

        #if optim.zero_grad():
            #optim.zero_grad()
        if optim_symp:
            optim_symp.zero_grad()
        losses_1.append(loss)

        # One had better keep tracking the diffeomorphism condition during the optimization.
        print(model.symp.is_diffeo)
        print("Iter {}: Loss= {:.6f}".format(epoch, loss))

        #break the gradient descent if the loss is under the certain level to avoid the fluctuation at later stage.
        if loss <= 1e-10:
          break

    print("Optimization Finished!")
    model.eval()
    print("The resulted symplectic matrix is:")
    print(model.symp.A)


if __name__ == "__main__":
    main()
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Iter 7024: Loss= 0.000288
# True
# Iter 7025: Loss= 0.000287
# True
# Iter 7026: Loss= 0.000286
# True
# Iter 7027: Loss= 0.000285
# True
# Iter 7028: Loss= 0.000285
# True
# Iter 7029: Loss= 0.000284
# True
# Iter 7030: Loss= 0.000283
# True
# Iter 7031: Loss= 0.000282
# True
# Iter 7032: Loss= 0.000281
# True
# Iter 7033: Loss= 0.000280
# True
# Iter 7034: Loss= 0.000279
# True
# Iter 7035: Loss= 0.000279
# True
# Iter 7036: Loss= 0.000278
# True
# Iter 7037: Loss= 0.000277
# True
# Iter 7038: Loss= 0.000276
# True
# Iter 7039: Loss= 0.000275
# True
# Iter 7040: Loss= 0.000274
# True
# Iter 7041: Loss= 0.000274
# True
# Iter 7042: Loss= 0.000273
# True
# Iter 7043: Loss= 0.000272
# True
# Iter 7044: Loss= 0.000271
# True
# Iter 7045: Loss= 0.000270
# True
# Iter 7046: Loss= 0.000269
# True
# Iter 7047: Loss= 0.000269
# True
# Iter 7048: Loss= 0.000268
# True
# Iter 7049: Loss= 0.000267
# True
# Iter 7050: Loss= 0.000266
# True
# Iter 7051: Loss= 0.000265
# True
# Iter 7052: Loss= 0.000265
# True
# Iter 7053: Loss= 0.000264
# True
# Iter 7054: Loss= 0.000263
# True
# Iter 7055: Loss= 0.000262
# True
# Iter 7056: Loss= 0.000261
# True
# Iter 7057: Loss= 0.000260
# True
# Iter 7058: Loss= 0.000260
# True
# Iter 7059: Loss= 0.000259
# True
# Iter 7060: Loss= 0.000258
# True
# Iter 7061: Loss= 0.000257
# True
# Iter 7062: Loss= 0.000257
# True
# Iter 7063: Loss= 0.000256
# True
# Iter 7064: Loss= 0.000255
# True
# Iter 7065: Loss= 0.000254
# True
# Iter 7066: Loss= 0.000253
# True
# Iter 7067: Loss= 0.000253
# True
# Iter 7068: Loss= 0.000252
# True
# Iter 7069: Loss= 0.000251
# True
# Iter 7070: Loss= 0.000250
# True
# Iter 7071: Loss= 0.000250
# True
# Iter 7072: Loss= 0.000249
# True
# Iter 7073: Loss= 0.000248
# True
# Iter 7074: Loss= 0.000247
# True
# Iter 7075: Loss= 0.000246
# True
# Iter 7076: Loss= 0.000246
# True
# Iter 7077: Loss= 0.000245
# True
# Iter 7078: Loss= 0.000244
# True
# Iter 7079: Loss= 0.000243
# True
# Iter 7080: Loss= 0.000243
# True
# Iter 7081: Loss= 0.000242
# True
# Iter 7082: Loss= 0.000241
# True
# Iter 7083: Loss= 0.000240
# True
# Iter 7084: Loss= 0.000240
# True
# Iter 7085: Loss= 0.000239
# True
# Iter 7086: Loss= 0.000238
# True
# Iter 7087: Loss= 0.000237
# True
# Iter 7088: Loss= 0.000237
# True
# Iter 7089: Loss= 0.000236
# True
# Iter 7090: Loss= 0.000235
# True
# Iter 7091: Loss= 0.000234
# True
# Iter 7092: Loss= 0.000234
# True
# Iter 7093: Loss= 0.000233
# True
# Iter 7094: Loss= 0.000232
# True
# Iter 7095: Loss= 0.000232
# True
# Iter 7096: Loss= 0.000231
# True
# Iter 7097: Loss= 0.000230
# True
# Iter 7098: Loss= 0.000229
# True
# Iter 7099: Loss= 0.000229
# True
# Iter 7100: Loss= 0.000228
# True
# Iter 7101: Loss= 0.000227
# True
# Iter 7102: Loss= 0.000227
# True
# Iter 7103: Loss= 0.000226
# True
# Iter 7104: Loss= 0.000225
# True
# Iter 7105: Loss= 0.000224
# True
# Iter 7106: Loss= 0.000224
# True
# Iter 7107: Loss= 0.000223
# True
# Iter 7108: Loss= 0.000222
# True
# Iter 7109: Loss= 0.000222
# True
# Iter 7110: Loss= 0.000221
# True
# Iter 7111: Loss= 0.000220
# True
# Iter 7112: Loss= 0.000220
# True
# Iter 7113: Loss= 0.000219
# True
# Iter 7114: Loss= 0.000218
# True
# Iter 7115: Loss= 0.000217
# True
# Iter 7116: Loss= 0.000217
# True
# Iter 7117: Loss= 0.000216
# True
# Iter 7118: Loss= 0.000215
# True
# Iter 7119: Loss= 0.000215
# True
# Iter 7120: Loss= 0.000214
# True
# Iter 7121: Loss= 0.000213
# True
# Iter 7122: Loss= 0.000213
# True
# Iter 7123: Loss= 0.000212
# True
# Iter 7124: Loss= 0.000211
# True
# Iter 7125: Loss= 0.000211
# True
# Iter 7126: Loss= 0.000210
# True
# Iter 7127: Loss= 0.000209
# True
# Iter 7128: Loss= 0.000209
# True
# Iter 7129: Loss= 0.000208
# True
# Iter 7130: Loss= 0.000207
# True
# Iter 7131: Loss= 0.000207
# True
# Iter 7132: Loss= 0.000206
# True
# Iter 7133: Loss= 0.000205
# True
# Iter 7134: Loss= 0.000205
# True
# Iter 7135: Loss= 0.000204
# True
# Iter 7136: Loss= 0.000203
# True
# Iter 7137: Loss= 0.000203
# True
# Iter 7138: Loss= 0.000202
# True
# Iter 7139: Loss= 0.000201
# True
# Iter 7140: Loss= 0.000201
# True
# Iter 7141: Loss= 0.000200
# True
# Iter 7142: Loss= 0.000200
# True
# Iter 7143: Loss= 0.000199
# True
# Iter 7144: Loss= 0.000198
# True
# Iter 7145: Loss= 0.000198
# True
# Iter 7146: Loss= 0.000197
# True
# Iter 7147: Loss= 0.000196
# True
# Iter 7148: Loss= 0.000196
# True
# Iter 7149: Loss= 0.000195
# True
# Iter 7150: Loss= 0.000194
# True
# Iter 7151: Loss= 0.000194
# True
# Iter 7152: Loss= 0.000193
# True
# Iter 7153: Loss= 0.000193
# True
# Iter 7154: Loss= 0.000192
# True
# Iter 7155: Loss= 0.000191
# True
# Iter 7156: Loss= 0.000191
# True
# Iter 7157: Loss= 0.000190
# True
# Iter 7158: Loss= 0.000190
# True
# Iter 7159: Loss= 0.000189
# True
# Iter 7160: Loss= 0.000188
# True
# Iter 7161: Loss= 0.000188
# True
# Iter 7162: Loss= 0.000187
# True
# Iter 7163: Loss= 0.000187
# True
# Iter 7164: Loss= 0.000186
# True
# Iter 7165: Loss= 0.000185
# True
# Iter 7166: Loss= 0.000185
# True
# Iter 7167: Loss= 0.000184
# True
# Iter 7168: Loss= 0.000184
# True
# Iter 7169: Loss= 0.000183
# True
# Iter 7170: Loss= 0.000182
# True
# Iter 7171: Loss= 0.000182
# True
# Iter 7172: Loss= 0.000181
# True
# Iter 7173: Loss= 0.000181
# True
# Iter 7174: Loss= 0.000180
# True
# Iter 7175: Loss= 0.000179
# True
# Iter 7176: Loss= 0.000179
# True
# Iter 7177: Loss= 0.000178
# True
# Iter 7178: Loss= 0.000178
# True
# Iter 7179: Loss= 0.000177
# True
# Iter 7180: Loss= 0.000176
# True
# Iter 7181: Loss= 0.000176
# True
# Iter 7182: Loss= 0.000175
# True
# Iter 7183: Loss= 0.000175
# True
# Iter 7184: Loss= 0.000174
# True
# Iter 7185: Loss= 0.000174
# True
# Iter 7186: Loss= 0.000173
# True
# Iter 7187: Loss= 0.000172
# True
# Iter 7188: Loss= 0.000172
# True
# Iter 7189: Loss= 0.000171
# True
# Iter 7190: Loss= 0.000171
# True
# Iter 7191: Loss= 0.000170
# True
# Iter 7192: Loss= 0.000170
# True
# Iter 7193: Loss= 0.000169
# True
# Iter 7194: Loss= 0.000169
# True
# Iter 7195: Loss= 0.000168
# True
# Iter 7196: Loss= 0.000167
# True
# Iter 7197: Loss= 0.000167
# True
# Iter 7198: Loss= 0.000166
# True
# Iter 7199: Loss= 0.000166
# True
# Iter 7200: Loss= 0.000165
# True
# Iter 7201: Loss= 0.000165
# True
# Iter 7202: Loss= 0.000164
# True
# Iter 7203: Loss= 0.000164
# True
# Iter 7204: Loss= 0.000163
# True
# Iter 7205: Loss= 0.000163
# True
# Iter 7206: Loss= 0.000162
# True
# Iter 7207: Loss= 0.000161
# True
# Iter 7208: Loss= 0.000161
# True
# Iter 7209: Loss= 0.000160
# True
# Iter 7210: Loss= 0.000160
# True
# Iter 7211: Loss= 0.000159
# True
# Iter 7212: Loss= 0.000159
# True
# Iter 7213: Loss= 0.000158
# True
# Iter 7214: Loss= 0.000158
# True
# Iter 7215: Loss= 0.000157
# True
# Iter 7216: Loss= 0.000157
# True
# Iter 7217: Loss= 0.000156
# True
# Iter 7218: Loss= 0.000156
# True
# Iter 7219: Loss= 0.000155
# True
# Iter 7220: Loss= 0.000155
# True
# Iter 7221: Loss= 0.000154
# True
# Iter 7222: Loss= 0.000154
# True
# Iter 7223: Loss= 0.000153
# True
# Iter 7224: Loss= 0.000153
# True
# Iter 7225: Loss= 0.000152
# True
# Iter 7226: Loss= 0.000152
# True
# Iter 7227: Loss= 0.000151
# True
# Iter 7228: Loss= 0.000151
# True
# Iter 7229: Loss= 0.000150
# True
# Iter 7230: Loss= 0.000150
# True
# Iter 7231: Loss= 0.000149
# True
# Iter 7232: Loss= 0.000149
# True
# Iter 7233: Loss= 0.000148
# True
# Iter 7234: Loss= 0.000148
# True
# Iter 7235: Loss= 0.000147
# True
# Iter 7236: Loss= 0.000147
# True
# Iter 7237: Loss= 0.000146
# True
# Iter 7238: Loss= 0.000146
# True
# Iter 7239: Loss= 0.000145
# True
# Iter 7240: Loss= 0.000145
# True
# Iter 7241: Loss= 0.000144
# True
# Iter 7242: Loss= 0.000144
# True
# Iter 7243: Loss= 0.000143
# True
# Iter 7244: Loss= 0.000143
# True
# Iter 7245: Loss= 0.000142
# True
# Iter 7246: Loss= 0.000142
# True
# Iter 7247: Loss= 0.000141
# True
# Iter 7248: Loss= 0.000141
# True
# Iter 7249: Loss= 0.000140
# True
# Iter 7250: Loss= 0.000140
# True
# Iter 7251: Loss= 0.000139
# True
# Iter 7252: Loss= 0.000139
# True
# Iter 7253: Loss= 0.000138
# True
# Iter 7254: Loss= 0.000138
# True
# Iter 7255: Loss= 0.000137
# True
# Iter 7256: Loss= 0.000137
# True
# Iter 7257: Loss= 0.000137
# True
# Iter 7258: Loss= 0.000136
# True
# Iter 7259: Loss= 0.000136
# True
# Iter 7260: Loss= 0.000135
# True
# Iter 7261: Loss= 0.000135
# True
# Iter 7262: Loss= 0.000134
# True
# Iter 7263: Loss= 0.000134
# True
# Iter 7264: Loss= 0.000133
# True
# Iter 7265: Loss= 0.000133
# True
# Iter 7266: Loss= 0.000132
# True
# Iter 7267: Loss= 0.000132
# True
# Iter 7268: Loss= 0.000132
# True
# Iter 7269: Loss= 0.000131
# True
# Iter 7270: Loss= 0.000131
# True
# Iter 7271: Loss= 0.000130
# True
# Iter 7272: Loss= 0.000130
# True
# Iter 7273: Loss= 0.000129
# True
# Iter 7274: Loss= 0.000129
# True
# Iter 7275: Loss= 0.000128
# True
# Iter 7276: Loss= 0.000128
# True
# Iter 7277: Loss= 0.000128
# True
# Iter 7278: Loss= 0.000127
# True
# Iter 7279: Loss= 0.000127
# True
# Iter 7280: Loss= 0.000126
# True
# Iter 7281: Loss= 0.000126
# True
# Iter 7282: Loss= 0.000125
# True
# Iter 7283: Loss= 0.000125
# True
# Iter 7284: Loss= 0.000125
# True
# Iter 7285: Loss= 0.000124
# True
# Iter 7286: Loss= 0.000124
# True
# Iter 7287: Loss= 0.000123
# True
# Iter 7288: Loss= 0.000123
# True
# Iter 7289: Loss= 0.000122
# True
# Iter 7290: Loss= 0.000122
# True
# Iter 7291: Loss= 0.000122
# True
# Iter 7292: Loss= 0.000121
# True
# Iter 7293: Loss= 0.000121
# True
# Iter 7294: Loss= 0.000120
# True
# Iter 7295: Loss= 0.000120
# True
# Iter 7296: Loss= 0.000119
# True
# Iter 7297: Loss= 0.000119
# True
# Iter 7298: Loss= 0.000119
# True
# Iter 7299: Loss= 0.000118
# True
# Iter 7300: Loss= 0.000118
# True
# Iter 7301: Loss= 0.000117
# True
# Iter 7302: Loss= 0.000117
# True
# Iter 7303: Loss= 0.000117
# True
# Iter 7304: Loss= 0.000116
# True
# Iter 7305: Loss= 0.000116
# True
# Iter 7306: Loss= 0.000115
# True
# Iter 7307: Loss= 0.000115
# True
# Iter 7308: Loss= 0.000115
# True
# Iter 7309: Loss= 0.000114
# True
# Iter 7310: Loss= 0.000114
# True
# Iter 7311: Loss= 0.000113
# True
# Iter 7312: Loss= 0.000113
# True
# Iter 7313: Loss= 0.000113
# True
# Iter 7314: Loss= 0.000112
# True
# Iter 7315: Loss= 0.000112
# True
# Iter 7316: Loss= 0.000111
# True
# Iter 7317: Loss= 0.000111
# True
# Iter 7318: Loss= 0.000111
# True
# Iter 7319: Loss= 0.000110
# True
# Iter 7320: Loss= 0.000110
# True
# Iter 7321: Loss= 0.000109
# True
# Iter 7322: Loss= 0.000109
# True
# Iter 7323: Loss= 0.000109
# True
# Iter 7324: Loss= 0.000108
# True
# Iter 7325: Loss= 0.000108
# True
# Iter 7326: Loss= 0.000108
# True
# Iter 7327: Loss= 0.000107
# True
# Iter 7328: Loss= 0.000107
# True
# Iter 7329: Loss= 0.000106
# True
# Iter 7330: Loss= 0.000106
# True
# Iter 7331: Loss= 0.000106
# True
# Iter 7332: Loss= 0.000105
# True
# Iter 7333: Loss= 0.000105
# True
# Iter 7334: Loss= 0.000105
# True
# Iter 7335: Loss= 0.000104
# True
# Iter 7336: Loss= 0.000104
# True
# Iter 7337: Loss= 0.000103
# True
# Iter 7338: Loss= 0.000103
# True
# Iter 7339: Loss= 0.000103
# True
# Iter 7340: Loss= 0.000102
# True
# Iter 7341: Loss= 0.000102
# True
# Iter 7342: Loss= 0.000102
# True
# Iter 7343: Loss= 0.000101
# True
# Iter 7344: Loss= 0.000101
# True
# Iter 7345: Loss= 0.000101
# True
# Iter 7346: Loss= 0.000100
# True
# Iter 7347: Loss= 0.000100
# True
# Iter 7348: Loss= 0.000100
# True
# Iter 7349: Loss= 0.000099
# True
# Iter 7350: Loss= 0.000099
# True
# Iter 7351: Loss= 0.000098
# True
# Iter 7352: Loss= 0.000098
# True
# Iter 7353: Loss= 0.000098
# True
# Iter 7354: Loss= 0.000097
# True
# Iter 7355: Loss= 0.000097
# True
# Iter 7356: Loss= 0.000097
# True
# Iter 7357: Loss= 0.000096
# True
# Iter 7358: Loss= 0.000096
# True
# Iter 7359: Loss= 0.000096
# True
# Iter 7360: Loss= 0.000095
# True
# Iter 7361: Loss= 0.000095
# True
# Iter 7362: Loss= 0.000095
# True
# Iter 7363: Loss= 0.000094
# True
# Iter 7364: Loss= 0.000094
# True
# Iter 7365: Loss= 0.000094
# True
# Iter 7366: Loss= 0.000093
# True
# Iter 7367: Loss= 0.000093
# True
# Iter 7368: Loss= 0.000093
# True
# Iter 7369: Loss= 0.000092
# True
# Iter 7370: Loss= 0.000092
# True
# Iter 7371: Loss= 0.000092
# True
# Iter 7372: Loss= 0.000091
# True
# Iter 7373: Loss= 0.000091
# True
# Iter 7374: Loss= 0.000091
# True
# Iter 7375: Loss= 0.000090
# True
# Iter 7376: Loss= 0.000090
# True
# Iter 7377: Loss= 0.000090
# True
# Iter 7378: Loss= 0.000089
# True
# Iter 7379: Loss= 0.000089
# True
# Iter 7380: Loss= 0.000089
# True
# Iter 7381: Loss= 0.000088
# True
# Iter 7382: Loss= 0.000088
# True
# Iter 7383: Loss= 0.000088
# True
# Iter 7384: Loss= 0.000087
# True
# Iter 7385: Loss= 0.000087
# True
# Iter 7386: Loss= 0.000087
# True
# Iter 7387: Loss= 0.000087
# True
# Iter 7388: Loss= 0.000086
# True
# Iter 7389: Loss= 0.000086
# True
# Iter 7390: Loss= 0.000086
# True
# Iter 7391: Loss= 0.000085
# True
# Iter 7392: Loss= 0.000085
# True
# Iter 7393: Loss= 0.000085
# True
# Iter 7394: Loss= 0.000084
# True
# Iter 7395: Loss= 0.000084
# True
# Iter 7396: Loss= 0.000084
# True
# Iter 7397: Loss= 0.000083
# True
# Iter 7398: Loss= 0.000083
# True
# Iter 7399: Loss= 0.000083
# True
# Iter 7400: Loss= 0.000083
# True
# Iter 7401: Loss= 0.000082
# True
# Iter 7402: Loss= 0.000082
# True
# Iter 7403: Loss= 0.000082
# True
# Iter 7404: Loss= 0.000081
# True
# Iter 7405: Loss= 0.000081
# True
# Iter 7406: Loss= 0.000081
# True
# Iter 7407: Loss= 0.000080
# True
# Iter 7408: Loss= 0.000080
# True
# Iter 7409: Loss= 0.000080
# True
# Iter 7410: Loss= 0.000080
# True
# Iter 7411: Loss= 0.000079
# True
# Iter 7412: Loss= 0.000079
# True
# Iter 7413: Loss= 0.000079
# True
# Iter 7414: Loss= 0.000078
# True
# Iter 7415: Loss= 0.000078
# True
# Iter 7416: Loss= 0.000078
# True
# Iter 7417: Loss= 0.000078
# True
# Iter 7418: Loss= 0.000077
# True
# Iter 7419: Loss= 0.000077
# True
# Iter 7420: Loss= 0.000077
# True
# Iter 7421: Loss= 0.000076
# True
# Iter 7422: Loss= 0.000076
# True
# Iter 7423: Loss= 0.000076
# True
# Iter 7424: Loss= 0.000076
# True
# Iter 7425: Loss= 0.000075
# True
# Iter 7426: Loss= 0.000075
# True
# Iter 7427: Loss= 0.000075
# True
# Iter 7428: Loss= 0.000074
# True
# Iter 7429: Loss= 0.000074
# True
# Iter 7430: Loss= 0.000074
# True
# Iter 7431: Loss= 0.000074
# True
# Iter 7432: Loss= 0.000073
# True
# Iter 7433: Loss= 0.000073
# True
# Iter 7434: Loss= 0.000073
# True
# Iter 7435: Loss= 0.000073
# True
# Iter 7436: Loss= 0.000072
# True
# Iter 7437: Loss= 0.000072
# True
# Iter 7438: Loss= 0.000072
# True
# Iter 7439: Loss= 0.000071
# True
# Iter 7440: Loss= 0.000071
# True
# Iter 7441: Loss= 0.000071
# True
# Iter 7442: Loss= 0.000071
# True
# Iter 7443: Loss= 0.000070
# True
# Iter 7444: Loss= 0.000070
# True
# Iter 7445: Loss= 0.000070
# True
# Iter 7446: Loss= 0.000070
# True
# Iter 7447: Loss= 0.000069
# True
# Iter 7448: Loss= 0.000069
# True
# Iter 7449: Loss= 0.000069
# True
# Iter 7450: Loss= 0.000069
# True
# Iter 7451: Loss= 0.000068
# True
# Iter 7452: Loss= 0.000068
# True
# Iter 7453: Loss= 0.000068
# True
# Iter 7454: Loss= 0.000068
# True
# Iter 7455: Loss= 0.000067
# True
# Iter 7456: Loss= 0.000067
# True
# Iter 7457: Loss= 0.000067
# True
# Iter 7458: Loss= 0.000067
# True
# Iter 7459: Loss= 0.000066
# True
# Iter 7460: Loss= 0.000066
# True
# Iter 7461: Loss= 0.000066
# True
# Iter 7462: Loss= 0.000066
# True
# Iter 7463: Loss= 0.000065
# True
# Iter 7464: Loss= 0.000065
# True
# Iter 7465: Loss= 0.000065
# True
# Iter 7466: Loss= 0.000065
# True
# Iter 7467: Loss= 0.000064
# True
# Iter 7468: Loss= 0.000064
# True
# Iter 7469: Loss= 0.000064
# True
# Iter 7470: Loss= 0.000064
# True
# Iter 7471: Loss= 0.000063
# True
# Iter 7472: Loss= 0.000063
# True
# Iter 7473: Loss= 0.000063
# True
# Iter 7474: Loss= 0.000063
# True
# Iter 7475: Loss= 0.000062
# True
# Iter 7476: Loss= 0.000062
# True
# Iter 7477: Loss= 0.000062
# True
# Iter 7478: Loss= 0.000062
# True
# Iter 7479: Loss= 0.000061
# True
# Iter 7480: Loss= 0.000061
# True
# Iter 7481: Loss= 0.000061
# True
# Iter 7482: Loss= 0.000061
# True
# Iter 7483: Loss= 0.000061
# True
# Iter 7484: Loss= 0.000060
# True
# Iter 7485: Loss= 0.000060
# True
# Iter 7486: Loss= 0.000060
# True
# Iter 7487: Loss= 0.000060
# True
# Iter 7488: Loss= 0.000059
# True
# Iter 7489: Loss= 0.000059
# True
# Iter 7490: Loss= 0.000059
# True
# Iter 7491: Loss= 0.000059
# True
# Iter 7492: Loss= 0.000059
# True
# Iter 7493: Loss= 0.000058
# True
# Iter 7494: Loss= 0.000058
# True
# Iter 7495: Loss= 0.000058
# True
# Iter 7496: Loss= 0.000058
# True
# Iter 7497: Loss= 0.000057
# True
# Iter 7498: Loss= 0.000057
# True
# Iter 7499: Loss= 0.000057
# True
# Iter 7500: Loss= 0.000057
# True
# Iter 7501: Loss= 0.000057
# True
# Iter 7502: Loss= 0.000056
# True
# Iter 7503: Loss= 0.000056
# True
# Iter 7504: Loss= 0.000056
# True
# Iter 7505: Loss= 0.000056
# True
# Iter 7506: Loss= 0.000055
# True
# Iter 7507: Loss= 0.000055
# True
# Iter 7508: Loss= 0.000055
# True
# Iter 7509: Loss= 0.000055
# True
# Iter 7510: Loss= 0.000055
# True
# Iter 7511: Loss= 0.000054
# True
# Iter 7512: Loss= 0.000054
# True
# Iter 7513: Loss= 0.000054
# True
# Iter 7514: Loss= 0.000054
# True
# Iter 7515: Loss= 0.000054
# True
# Iter 7516: Loss= 0.000053
# True
# Iter 7517: Loss= 0.000053
# True
# Iter 7518: Loss= 0.000053
# True
# Iter 7519: Loss= 0.000053
# True
# Iter 7520: Loss= 0.000053
# True
# Iter 7521: Loss= 0.000052
# True
# Iter 7522: Loss= 0.000052
# True
# Iter 7523: Loss= 0.000052
# True
# Iter 7524: Loss= 0.000052
# True
# Iter 7525: Loss= 0.000052
# True
# Iter 7526: Loss= 0.000051
# True
# Iter 7527: Loss= 0.000051
# True
# Iter 7528: Loss= 0.000051
# True
# Iter 7529: Loss= 0.000051
# True
# Iter 7530: Loss= 0.000051
# True
# Iter 7531: Loss= 0.000050
# True
# Iter 7532: Loss= 0.000050
# True
# Iter 7533: Loss= 0.000050
# True
# Iter 7534: Loss= 0.000050
# True
# Iter 7535: Loss= 0.000050
# True
# Iter 7536: Loss= 0.000049
# True
# Iter 7537: Loss= 0.000049
# True
# Iter 7538: Loss= 0.000049
# True
# Iter 7539: Loss= 0.000049
# True
# Iter 7540: Loss= 0.000049
# True
# Iter 7541: Loss= 0.000048
# True
# Iter 7542: Loss= 0.000048
# True
# Iter 7543: Loss= 0.000048
# True
# Iter 7544: Loss= 0.000048
# True
# Iter 7545: Loss= 0.000048
# True
# Iter 7546: Loss= 0.000047
# True
# Iter 7547: Loss= 0.000047
# True
# Iter 7548: Loss= 0.000047
# True
# Iter 7549: Loss= 0.000047
# True
# Iter 7550: Loss= 0.000047
# True
# Iter 7551: Loss= 0.000047
# True
# Iter 7552: Loss= 0.000046
# True
# Iter 7553: Loss= 0.000046
# True
# Iter 7554: Loss= 0.000046
# True
# Iter 7555: Loss= 0.000046
# True
# Iter 7556: Loss= 0.000046
# True
# Iter 7557: Loss= 0.000045
# True
# Iter 7558: Loss= 0.000045
# True
# Iter 7559: Loss= 0.000045
# True
# Iter 7560: Loss= 0.000045
# True
# Iter 7561: Loss= 0.000045
# True
# Iter 7562: Loss= 0.000045
# True
# Iter 7563: Loss= 0.000044
# True
# Iter 7564: Loss= 0.000044
# True
# Iter 7565: Loss= 0.000044
# True
# Iter 7566: Loss= 0.000044
# True
# Iter 7567: Loss= 0.000044
# True
# Iter 7568: Loss= 0.000044
# True
# Iter 7569: Loss= 0.000043
# True
# Iter 7570: Loss= 0.000043
# True
# Iter 7571: Loss= 0.000043
# True
# Iter 7572: Loss= 0.000043
# True
# Iter 7573: Loss= 0.000043
# True
# Iter 7574: Loss= 0.000042
# True
# Iter 7575: Loss= 0.000042
# True
# Iter 7576: Loss= 0.000042
# True
# Iter 7577: Loss= 0.000042
# True
# Iter 7578: Loss= 0.000042
# True
# Iter 7579: Loss= 0.000042
# True
# Iter 7580: Loss= 0.000041
# True
# Iter 7581: Loss= 0.000041
# True
# Iter 7582: Loss= 0.000041
# True
# Iter 7583: Loss= 0.000041
# True
# Iter 7584: Loss= 0.000041
# True
# Iter 7585: Loss= 0.000041
# True
# Iter 7586: Loss= 0.000040
# True
# Iter 7587: Loss= 0.000040
# True
# Iter 7588: Loss= 0.000040
# True
# Iter 7589: Loss= 0.000040
# True
# Iter 7590: Loss= 0.000040
# True
# Iter 7591: Loss= 0.000040
# True
# Iter 7592: Loss= 0.000040
# True
# Iter 7593: Loss= 0.000039
# True
# Iter 7594: Loss= 0.000039
# True
# Iter 7595: Loss= 0.000039
# True
# Iter 7596: Loss= 0.000039
# True
# Iter 7597: Loss= 0.000039
# True
# Iter 7598: Loss= 0.000039
# True
# Iter 7599: Loss= 0.000038
# True
# Iter 7600: Loss= 0.000038
# True
# Iter 7601: Loss= 0.000038
# True
# Iter 7602: Loss= 0.000038
# True
# Iter 7603: Loss= 0.000038
# True
# Iter 7604: Loss= 0.000038
# True
# Iter 7605: Loss= 0.000037
# True
# Iter 7606: Loss= 0.000037
# True
# Iter 7607: Loss= 0.000037
# True
# Iter 7608: Loss= 0.000037
# True
# Iter 7609: Loss= 0.000037
# True
# Iter 7610: Loss= 0.000037
# True
# Iter 7611: Loss= 0.000037
# True
# Iter 7612: Loss= 0.000036
# True
# Iter 7613: Loss= 0.000036
# True
# Iter 7614: Loss= 0.000036
# True
# Iter 7615: Loss= 0.000036
# True
# Iter 7616: Loss= 0.000036
# True
# Iter 7617: Loss= 0.000036
# True
# Iter 7618: Loss= 0.000036
# True
# Iter 7619: Loss= 0.000035
# True
# Iter 7620: Loss= 0.000035
# True
# Iter 7621: Loss= 0.000035
# True
# Iter 7622: Loss= 0.000035
# True
# Iter 7623: Loss= 0.000035
# True
# Iter 7624: Loss= 0.000035
# True
# Iter 7625: Loss= 0.000035
# True
# Iter 7626: Loss= 0.000034
# True
# Iter 7627: Loss= 0.000034
# True
# Iter 7628: Loss= 0.000034
# True
# Iter 7629: Loss= 0.000034
# True
# Iter 7630: Loss= 0.000034
# True
# Iter 7631: Loss= 0.000034
# True
# Iter 7632: Loss= 0.000034
# True
# Iter 7633: Loss= 0.000033
# True
# Iter 7634: Loss= 0.000033
# True
# Iter 7635: Loss= 0.000033
# True
# Iter 7636: Loss= 0.000033
# True
# Iter 7637: Loss= 0.000033
# True
# Iter 7638: Loss= 0.000033
# True
# Iter 7639: Loss= 0.000033
# True
# Iter 7640: Loss= 0.000032
# True
# Iter 7641: Loss= 0.000032
# True
# Iter 7642: Loss= 0.000032
# True
# Iter 7643: Loss= 0.000032
# True
# Iter 7644: Loss= 0.000032
# True
# Iter 7645: Loss= 0.000032
# True
# Iter 7646: Loss= 0.000032
# True
# Iter 7647: Loss= 0.000032
# True
# Iter 7648: Loss= 0.000031
# True
# Iter 7649: Loss= 0.000031
# True
# Iter 7650: Loss= 0.000031
# True
# Iter 7651: Loss= 0.000031
# True
# Iter 7652: Loss= 0.000031
# True
# Iter 7653: Loss= 0.000031
# True
# Iter 7654: Loss= 0.000031
# True
# Iter 7655: Loss= 0.000031
# True
# Iter 7656: Loss= 0.000030
# True
# Iter 7657: Loss= 0.000030
# True
# Iter 7658: Loss= 0.000030
# True
# Iter 7659: Loss= 0.000030
# True
# Iter 7660: Loss= 0.000030
# True
# Iter 7661: Loss= 0.000030
# True
# Iter 7662: Loss= 0.000030
# True
# Iter 7663: Loss= 0.000030
# True
# Iter 7664: Loss= 0.000029
# True
# Iter 7665: Loss= 0.000029
# True
# Iter 7666: Loss= 0.000029
# True
# Iter 7667: Loss= 0.000029
# True
# Iter 7668: Loss= 0.000029
# True
# Iter 7669: Loss= 0.000029
# True
# Iter 7670: Loss= 0.000029
# True
# Iter 7671: Loss= 0.000029
# True
# Iter 7672: Loss= 0.000028
# True
# Iter 7673: Loss= 0.000028
# True
# Iter 7674: Loss= 0.000028
# True
# Iter 7675: Loss= 0.000028
# True
# Iter 7676: Loss= 0.000028
# True
# Iter 7677: Loss= 0.000028
# True
# Iter 7678: Loss= 0.000028
# True
# Iter 7679: Loss= 0.000028
# True
# Iter 7680: Loss= 0.000028
# True
# Iter 7681: Loss= 0.000027
# True
# Iter 7682: Loss= 0.000027
# True
# Iter 7683: Loss= 0.000027
# True
# Iter 7684: Loss= 0.000027
# True
# Iter 7685: Loss= 0.000027
# True
# Iter 7686: Loss= 0.000027
# True
# Iter 7687: Loss= 0.000027
# True
# Iter 7688: Loss= 0.000027
# True
# Iter 7689: Loss= 0.000026
# True
# Iter 7690: Loss= 0.000026
# True
# Iter 7691: Loss= 0.000026
# True
# Iter 7692: Loss= 0.000026
# True
# Iter 7693: Loss= 0.000026
# True
# Iter 7694: Loss= 0.000026
# True
# Iter 7695: Loss= 0.000026
# True
# Iter 7696: Loss= 0.000026
# True
# Iter 7697: Loss= 0.000026
# True
# Iter 7698: Loss= 0.000025
# True
# Iter 7699: Loss= 0.000025
# True
# Iter 7700: Loss= 0.000025
# True
# Iter 7701: Loss= 0.000025
# True
# Iter 7702: Loss= 0.000025
# True
# Iter 7703: Loss= 0.000025
# True
# Iter 7704: Loss= 0.000025
# True
# Iter 7705: Loss= 0.000025
# True
# Iter 7706: Loss= 0.000025
# True
# Iter 7707: Loss= 0.000025
# True
# Iter 7708: Loss= 0.000024
# True
# Iter 7709: Loss= 0.000024
# True
# Iter 7710: Loss= 0.000024
# True
# Iter 7711: Loss= 0.000024
# True
# Iter 7712: Loss= 0.000024
# True
# Iter 7713: Loss= 0.000024
# True
# Iter 7714: Loss= 0.000024
# True
# Iter 7715: Loss= 0.000024
# True
# Iter 7716: Loss= 0.000024
# True
# Iter 7717: Loss= 0.000024
# True
# Iter 7718: Loss= 0.000023
# True
# Iter 7719: Loss= 0.000023
# True
# Iter 7720: Loss= 0.000023
# True
# Iter 7721: Loss= 0.000023
# True
# Iter 7722: Loss= 0.000023
# True
# Iter 7723: Loss= 0.000023
# True
# Iter 7724: Loss= 0.000023
# True
# Iter 7725: Loss= 0.000023
# True
# Iter 7726: Loss= 0.000023
# True
# Iter 7727: Loss= 0.000023
# True
# Iter 7728: Loss= 0.000022
# True
# Iter 7729: Loss= 0.000022
# True
# Iter 7730: Loss= 0.000022
# True
# Iter 7731: Loss= 0.000022
# True
# Iter 7732: Loss= 0.000022
# True
# Iter 7733: Loss= 0.000022
# True
# Iter 7734: Loss= 0.000022
# True
# Iter 7735: Loss= 0.000022
# True
# Iter 7736: Loss= 0.000022
# True
# Iter 7737: Loss= 0.000022
# True
# Iter 7738: Loss= 0.000021
# True
# Iter 7739: Loss= 0.000021
# True
# Iter 7740: Loss= 0.000021
# True
# Iter 7741: Loss= 0.000021
# True
# Iter 7742: Loss= 0.000021
# True
# Iter 7743: Loss= 0.000021
# True
# Iter 7744: Loss= 0.000021
# True
# Iter 7745: Loss= 0.000021
# True
# Iter 7746: Loss= 0.000021
# True
# Iter 7747: Loss= 0.000021
# True
# Iter 7748: Loss= 0.000021
# True
# Iter 7749: Loss= 0.000020
# True
# Iter 7750: Loss= 0.000020
# True
# Iter 7751: Loss= 0.000020
# True
# Iter 7752: Loss= 0.000020
# True
# Iter 7753: Loss= 0.000020
# True
# Iter 7754: Loss= 0.000020
# True
# Iter 7755: Loss= 0.000020
# True
# Iter 7756: Loss= 0.000020
# True
# Iter 7757: Loss= 0.000020
# True
# Iter 7758: Loss= 0.000020
# True
# Iter 7759: Loss= 0.000020
# True
# Iter 7760: Loss= 0.000020
# True
# Iter 7761: Loss= 0.000019
# True
# Iter 7762: Loss= 0.000019
# True
# Iter 7763: Loss= 0.000019
# True
# Iter 7764: Loss= 0.000019
# True
# Iter 7765: Loss= 0.000019
# True
# Iter 7766: Loss= 0.000019
# True
# Iter 7767: Loss= 0.000019
# True
# Iter 7768: Loss= 0.000019
# True
# Iter 7769: Loss= 0.000019
# True
# Iter 7770: Loss= 0.000019
# True
# Iter 7771: Loss= 0.000019
# True
# Iter 7772: Loss= 0.000019
# True
# Iter 7773: Loss= 0.000018
# True
# Iter 7774: Loss= 0.000018
# True
# Iter 7775: Loss= 0.000018
# True
# Iter 7776: Loss= 0.000018
# True
# Iter 7777: Loss= 0.000018
# True
# Iter 7778: Loss= 0.000018
# True
# Iter 7779: Loss= 0.000018
# True
# Iter 7780: Loss= 0.000018
# True
# Iter 7781: Loss= 0.000018
# True
# Iter 7782: Loss= 0.000018
# True
# Iter 7783: Loss= 0.000018
# True
# Iter 7784: Loss= 0.000018
# True
# Iter 7785: Loss= 0.000017
# True
# Iter 7786: Loss= 0.000017
# True
# Iter 7787: Loss= 0.000017
# True
# Iter 7788: Loss= 0.000017
# True
# Iter 7789: Loss= 0.000017
# True
# Iter 7790: Loss= 0.000017
# True
# Iter 7791: Loss= 0.000017
# True
# Iter 7792: Loss= 0.000017
# True
# Iter 7793: Loss= 0.000017
# True
# Iter 7794: Loss= 0.000017
# True
# Iter 7795: Loss= 0.000017
# True
# Iter 7796: Loss= 0.000017
# True
# Iter 7797: Loss= 0.000017
# True
# Iter 7798: Loss= 0.000016
# True
# Iter 7799: Loss= 0.000016
# True
# Iter 7800: Loss= 0.000016
# True
# Iter 7801: Loss= 0.000016
# True
# Iter 7802: Loss= 0.000016
# True
# Iter 7803: Loss= 0.000016
# True
# Iter 7804: Loss= 0.000016
# True
# Iter 7805: Loss= 0.000016
# True
# Iter 7806: Loss= 0.000016
# True
# Iter 7807: Loss= 0.000016
# True
# Iter 7808: Loss= 0.000016
# True
# Iter 7809: Loss= 0.000016
# True
# Iter 7810: Loss= 0.000016
# True
# Iter 7811: Loss= 0.000016
# True
# Iter 7812: Loss= 0.000015
# True
# Iter 7813: Loss= 0.000015
# True
# Iter 7814: Loss= 0.000015
# True
# Iter 7815: Loss= 0.000015
# True
# Iter 7816: Loss= 0.000015
# True
# Iter 7817: Loss= 0.000015
# True
# Iter 7818: Loss= 0.000015
# True
# Iter 7819: Loss= 0.000015
# True
# Iter 7820: Loss= 0.000015
# True
# Iter 7821: Loss= 0.000015
# True
# Iter 7822: Loss= 0.000015
# True
# Iter 7823: Loss= 0.000015
# True
# Iter 7824: Loss= 0.000015
# True
# Iter 7825: Loss= 0.000015
# True
# Iter 7826: Loss= 0.000015
# True
# Iter 7827: Loss= 0.000014
# True
# Iter 7828: Loss= 0.000014
# True
# Iter 7829: Loss= 0.000014
# True
# Iter 7830: Loss= 0.000014
# True
# Iter 7831: Loss= 0.000014
# True
# Iter 7832: Loss= 0.000014
# True
# Iter 7833: Loss= 0.000014
# True
# Iter 7834: Loss= 0.000014
# True
# Iter 7835: Loss= 0.000014
# True
# Iter 7836: Loss= 0.000014
# True
# Iter 7837: Loss= 0.000014
# True
# Iter 7838: Loss= 0.000014
# True
# Iter 7839: Loss= 0.000014
# True
# Iter 7840: Loss= 0.000014
# True
# Iter 7841: Loss= 0.000014
# True
# Iter 7842: Loss= 0.000014
# True
# Iter 7843: Loss= 0.000013
# True
# Iter 7844: Loss= 0.000013
# True
# Iter 7845: Loss= 0.000013
# True
# Iter 7846: Loss= 0.000013
# True
# Iter 7847: Loss= 0.000013
# True
# Iter 7848: Loss= 0.000013
# True
# Iter 7849: Loss= 0.000013
# True
# Iter 7850: Loss= 0.000013
# True
# Iter 7851: Loss= 0.000013
# True
# Iter 7852: Loss= 0.000013
# True
# Iter 7853: Loss= 0.000013
# True
# Iter 7854: Loss= 0.000013
# True
# Iter 7855: Loss= 0.000013
# True
# Iter 7856: Loss= 0.000013
# True
# Iter 7857: Loss= 0.000013
# True
# Iter 7858: Loss= 0.000013
# True
# Iter 7859: Loss= 0.000012
# True
# Iter 7860: Loss= 0.000012
# True
# Iter 7861: Loss= 0.000012
# True
# Iter 7862: Loss= 0.000012
# True
# Iter 7863: Loss= 0.000012
# True
# Iter 7864: Loss= 0.000012
# True
# Iter 7865: Loss= 0.000012
# True
# Iter 7866: Loss= 0.000012
# True
# Iter 7867: Loss= 0.000012
# True
# Iter 7868: Loss= 0.000012
# True
# Iter 7869: Loss= 0.000012
# True
# Iter 7870: Loss= 0.000012
# True
# Iter 7871: Loss= 0.000012
# True
# Iter 7872: Loss= 0.000012
# True
# Iter 7873: Loss= 0.000012
# True
# Iter 7874: Loss= 0.000012
# True
# Iter 7875: Loss= 0.000012
# True
# Iter 7876: Loss= 0.000012
# True
# Iter 7877: Loss= 0.000011
# True
# Iter 7878: Loss= 0.000011
# True
# Iter 7879: Loss= 0.000011
# True
# Iter 7880: Loss= 0.000011
# True
# Iter 7881: Loss= 0.000011
# True
# Iter 7882: Loss= 0.000011
# True
# Iter 7883: Loss= 0.000011
# True
# Iter 7884: Loss= 0.000011
# True
# Iter 7885: Loss= 0.000011
# True
# Iter 7886: Loss= 0.000011
# True
# Iter 7887: Loss= 0.000011
# True
# Iter 7888: Loss= 0.000011
# True
# Iter 7889: Loss= 0.000011
# True
# Iter 7890: Loss= 0.000011
# True
# Iter 7891: Loss= 0.000011
# True
# Iter 7892: Loss= 0.000011
# True
# Iter 7893: Loss= 0.000011
# True
# Iter 7894: Loss= 0.000011
# True
# Iter 7895: Loss= 0.000011
# True
# Iter 7896: Loss= 0.000011
# True
# Iter 7897: Loss= 0.000010
# True
# Iter 7898: Loss= 0.000010
# True
# Iter 7899: Loss= 0.000010
# True
# Iter 7900: Loss= 0.000010
# True
# Iter 7901: Loss= 0.000010
# True
# Iter 7902: Loss= 0.000010
# True
# Iter 7903: Loss= 0.000010
# True
# Iter 7904: Loss= 0.000010
# True
# Iter 7905: Loss= 0.000010
# True
# Iter 7906: Loss= 0.000010
# True
# Iter 7907: Loss= 0.000010
# True
# Iter 7908: Loss= 0.000010
# True
# Iter 7909: Loss= 0.000010
# True
# Iter 7910: Loss= 0.000010
# True
# Iter 7911: Loss= 0.000010
# True
# Iter 7912: Loss= 0.000010
# True
# Iter 7913: Loss= 0.000010
# True
# Iter 7914: Loss= 0.000010
# True
# Iter 7915: Loss= 0.000010
# True
# Iter 7916: Loss= 0.000010
# True
# Iter 7917: Loss= 0.000010
# True
# Iter 7918: Loss= 0.000009
# True
# Iter 7919: Loss= 0.000009
# True
# Iter 7920: Loss= 0.000009
# True
# Iter 7921: Loss= 0.000009
# True
# Iter 7922: Loss= 0.000009
# True
# Iter 7923: Loss= 0.000009
# True
# Iter 7924: Loss= 0.000009
# True
# Iter 7925: Loss= 0.000009
# True
# Iter 7926: Loss= 0.000009
# True
# Iter 7927: Loss= 0.000009
# True
# Iter 7928: Loss= 0.000009
# True
# Iter 7929: Loss= 0.000009
# True
# Iter 7930: Loss= 0.000009
# True
# Iter 7931: Loss= 0.000009
# True
# Iter 7932: Loss= 0.000009
# True
# Iter 7933: Loss= 0.000009
# True
# Iter 7934: Loss= 0.000009
# True
# Iter 7935: Loss= 0.000009
# True
# Iter 7936: Loss= 0.000009
# True
# Iter 7937: Loss= 0.000009
# True
# Iter 7938: Loss= 0.000009
# True
# Iter 7939: Loss= 0.000009
# True
# Iter 7940: Loss= 0.000009
# True
# Iter 7941: Loss= 0.000008
# True
# Iter 7942: Loss= 0.000008
# True
# Iter 7943: Loss= 0.000008
# True
# Iter 7944: Loss= 0.000008
# True
# Iter 7945: Loss= 0.000008
# True
# Iter 7946: Loss= 0.000008
# True
# Iter 7947: Loss= 0.000008
# True
# Iter 7948: Loss= 0.000008
# True
# Iter 7949: Loss= 0.000008
# True
# Iter 7950: Loss= 0.000008
# True
# Iter 7951: Loss= 0.000008
# True
# Iter 7952: Loss= 0.000008
# True
# Iter 7953: Loss= 0.000008
# True
# Iter 7954: Loss= 0.000008
# True
# Iter 7955: Loss= 0.000008
# True
# Iter 7956: Loss= 0.000008
# True
# Iter 7957: Loss= 0.000008
# True
# Iter 7958: Loss= 0.000008
# True
# Iter 7959: Loss= 0.000008
# True
# Iter 7960: Loss= 0.000008
# True
# Iter 7961: Loss= 0.000008
# True
# Iter 7962: Loss= 0.000008
# True
# Iter 7963: Loss= 0.000008
# True
# Iter 7964: Loss= 0.000008
# True
# Iter 7965: Loss= 0.000008
# True
# Iter 7966: Loss= 0.000008
# True
# Iter 7967: Loss= 0.000008
# True
# Iter 7968: Loss= 0.000007
# True
# Iter 7969: Loss= 0.000007
# True
# Iter 7970: Loss= 0.000007
# True
# Iter 7971: Loss= 0.000007
# True
# Iter 7972: Loss= 0.000007
# True
# Iter 7973: Loss= 0.000007
# True
# Iter 7974: Loss= 0.000008
# True
# Iter 7975: Loss= 0.000008
# True
# Iter 7976: Loss= 0.000008
# True
# Iter 7977: Loss= 0.000008
# True
# Iter 7978: Loss= 0.000009
# True
# Iter 7979: Loss= 0.000010
# True
# Iter 7980: Loss= 0.000011
# True
# Iter 7981: Loss= 0.000012
# True
# Iter 7982: Loss= 0.000013
# True
# Iter 7983: Loss= 0.000013
# True
# Iter 7984: Loss= 0.000012
# True
# Iter 7985: Loss= 0.000010
# True
# Iter 7986: Loss= 0.000008
# True
# Iter 7987: Loss= 0.000007
# True
# Iter 7988: Loss= 0.000007
# True
# Iter 7989: Loss= 0.000008
# True
# Iter 7990: Loss= 0.000009
# True
# Iter 7991: Loss= 0.000009
# True
# Iter 7992: Loss= 0.000008
# True
# Iter 7993: Loss= 0.000007
# True
# Iter 7994: Loss= 0.000007
# True
# Iter 7995: Loss= 0.000007
# True
# Iter 7996: Loss= 0.000007
# True
# Iter 7997: Loss= 0.000008
# True
# Iter 7998: Loss= 0.000008
# True
# Iter 7999: Loss= 0.000007
# True
# Iter 8000: Loss= 0.000007
# True
# Iter 8001: Loss= 0.000006
# True
# Iter 8002: Loss= 0.000006
# True
# Iter 8003: Loss= 0.000007
# True
# Iter 8004: Loss= 0.000007
# True
# Iter 8005: Loss= 0.000007
# True
# Iter 8006: Loss= 0.000006
# True
# Iter 8007: Loss= 0.000006
# True
# Iter 8008: Loss= 0.000006
# True
# Iter 8009: Loss= 0.000006
# True
# Iter 8010: Loss= 0.000006
# True
# Iter 8011: Loss= 0.000006
# True
# Iter 8012: Loss= 0.000006
# True
# Iter 8013: Loss= 0.000006
# True
# Iter 8014: Loss= 0.000006
# True
# Iter 8015: Loss= 0.000006
# True
# Iter 8016: Loss= 0.000006
# True
# Iter 8017: Loss= 0.000006
# True
# Iter 8018: Loss= 0.000006
# True
# Iter 8019: Loss= 0.000006
# True
# Iter 8020: Loss= 0.000006
# True
# Iter 8021: Loss= 0.000006
# True
# Iter 8022: Loss= 0.000006
# True
# Iter 8023: Loss= 0.000006
# True
# Iter 8024: Loss= 0.000006
# True
# Iter 8025: Loss= 0.000006
# True
# Iter 8026: Loss= 0.000006
# True
# Iter 8027: Loss= 0.000006
# True
# Iter 8028: Loss= 0.000006
# True
# Iter 8029: Loss= 0.000006
# True
# Iter 8030: Loss= 0.000006
# True
# Iter 8031: Loss= 0.000005
# True
# Iter 8032: Loss= 0.000005
# True
# Iter 8033: Loss= 0.000005
# True
# Iter 8034: Loss= 0.000005
# True
# Iter 8035: Loss= 0.000005
# True
# Iter 8036: Loss= 0.000005
# True
# Iter 8037: Loss= 0.000005
# True
# Iter 8038: Loss= 0.000005
# True
# Iter 8039: Loss= 0.000005
# True
# Iter 8040: Loss= 0.000005
# True
# Iter 8041: Loss= 0.000005
# True
# Iter 8042: Loss= 0.000005
# True
# Iter 8043: Loss= 0.000005
# True
# Iter 8044: Loss= 0.000005
# True
# Iter 8045: Loss= 0.000005
# True
# Iter 8046: Loss= 0.000005
# True
# Iter 8047: Loss= 0.000005
# True
# Iter 8048: Loss= 0.000005
# True
# Iter 8049: Loss= 0.000005
# True
# Iter 8050: Loss= 0.000005
# True
# Iter 8051: Loss= 0.000005
# True
# Iter 8052: Loss= 0.000005
# True
# Iter 8053: Loss= 0.000005
# True
# Iter 8054: Loss= 0.000005
# True
# Iter 8055: Loss= 0.000005
# True
# Iter 8056: Loss= 0.000005
# True
# Iter 8057: Loss= 0.000005
# True
# Iter 8058: Loss= 0.000005
# True
# Iter 8059: Loss= 0.000005
# True
# Iter 8060: Loss= 0.000005
# True
# Iter 8061: Loss= 0.000005
# True
# Iter 8062: Loss= 0.000005
# True
# Iter 8063: Loss= 0.000005
# True
# Iter 8064: Loss= 0.000005
# True
# Iter 8065: Loss= 0.000005
# True
# Iter 8066: Loss= 0.000005
# True
# Iter 8067: Loss= 0.000005
# True
# Iter 8068: Loss= 0.000005
# True
# Iter 8069: Loss= 0.000004
# True
# Iter 8070: Loss= 0.000004
# True
# Iter 8071: Loss= 0.000004
# True
# Iter 8072: Loss= 0.000004
# True
# Iter 8073: Loss= 0.000004
# True
# Iter 8074: Loss= 0.000004
# True
# Iter 8075: Loss= 0.000004
# True
# Iter 8076: Loss= 0.000004
# True
# Iter 8077: Loss= 0.000004
# True
# Iter 8078: Loss= 0.000004
# True
# Iter 8079: Loss= 0.000004
# True
# Iter 8080: Loss= 0.000004
# True
# Iter 8081: Loss= 0.000004
# True
# Iter 8082: Loss= 0.000004
# True
# Iter 8083: Loss= 0.000004
# True
# Iter 8084: Loss= 0.000004
# True
# Iter 8085: Loss= 0.000004
# True
# Iter 8086: Loss= 0.000004
# True
# Iter 8087: Loss= 0.000004
# True
# Iter 8088: Loss= 0.000004
# True
# Iter 8089: Loss= 0.000004
# True
# Iter 8090: Loss= 0.000004
# True
# Iter 8091: Loss= 0.000004
# True
# Iter 8092: Loss= 0.000004
# True
# Iter 8093: Loss= 0.000004
# True
# Iter 8094: Loss= 0.000004
# True
# Iter 8095: Loss= 0.000004
# True
# Iter 8096: Loss= 0.000004
# True
# Iter 8097: Loss= 0.000004
# True
# Iter 8098: Loss= 0.000004
# True
# Iter 8099: Loss= 0.000004
# True
# Iter 8100: Loss= 0.000004
# True
# Iter 8101: Loss= 0.000004
# True
# Iter 8102: Loss= 0.000004
# True
# Iter 8103: Loss= 0.000004
# True
# Iter 8104: Loss= 0.000004
# True
# Iter 8105: Loss= 0.000004
# True
# Iter 8106: Loss= 0.000004
# True
# Iter 8107: Loss= 0.000004
# True
# Iter 8108: Loss= 0.000004
# True
# Iter 8109: Loss= 0.000004
# True
# Iter 8110: Loss= 0.000004
# True
# Iter 8111: Loss= 0.000004
# True
# Iter 8112: Loss= 0.000004
# True
# Iter 8113: Loss= 0.000004
# True
# Iter 8114: Loss= 0.000004
# True
# Iter 8115: Loss= 0.000004
# True
# Iter 8116: Loss= 0.000004
# True
# Iter 8117: Loss= 0.000004
# True
# Iter 8118: Loss= 0.000003
# True
# Iter 8119: Loss= 0.000003
# True
# Iter 8120: Loss= 0.000003
# True
# Iter 8121: Loss= 0.000003
# True
# Iter 8122: Loss= 0.000003
# True
# Iter 8123: Loss= 0.000003
# True
# Iter 8124: Loss= 0.000003
# True
# Iter 8125: Loss= 0.000003
# True
# Iter 8126: Loss= 0.000003
# True
# Iter 8127: Loss= 0.000003
# True
# Iter 8128: Loss= 0.000003
# True
# Iter 8129: Loss= 0.000003
# True
# Iter 8130: Loss= 0.000003
# True
# Iter 8131: Loss= 0.000003
# True
# Iter 8132: Loss= 0.000003
# True
# Iter 8133: Loss= 0.000003
# True
# Iter 8134: Loss= 0.000003
# True
# Iter 8135: Loss= 0.000003
# True
# Iter 8136: Loss= 0.000003
# True
# Iter 8137: Loss= 0.000003
# True
# Iter 8138: Loss= 0.000003
# True
# Iter 8139: Loss= 0.000003
# True
# Iter 8140: Loss= 0.000003
# True
# Iter 8141: Loss= 0.000003
# True
# Iter 8142: Loss= 0.000003
# True
# Iter 8143: Loss= 0.000003
# True
# Iter 8144: Loss= 0.000003
# True
# Iter 8145: Loss= 0.000003
# True
# Iter 8146: Loss= 0.000003
# True
# Iter 8147: Loss= 0.000003
# True
# Iter 8148: Loss= 0.000003
# True
# Iter 8149: Loss= 0.000003
# True
# Iter 8150: Loss= 0.000003
# True
# Iter 8151: Loss= 0.000003
# True
# Iter 8152: Loss= 0.000003
# True
# Iter 8153: Loss= 0.000003
# True
# Iter 8154: Loss= 0.000003
# True
# Iter 8155: Loss= 0.000003
# True
# Iter 8156: Loss= 0.000003
# True
# Iter 8157: Loss= 0.000003
# True
# Iter 8158: Loss= 0.000003
# True
# Iter 8159: Loss= 0.000003
# True
# Iter 8160: Loss= 0.000003
# True
# Iter 8161: Loss= 0.000003
# True
# Iter 8162: Loss= 0.000003
# True
# Iter 8163: Loss= 0.000003
# True
# Iter 8164: Loss= 0.000003
# True
# Iter 8165: Loss= 0.000004
# True
# Iter 8166: Loss= 0.000004
# True
# Iter 8167: Loss= 0.000004
# True
# Iter 8168: Loss= 0.000005
# True
# Iter 8169: Loss= 0.000006
# True
# Iter 8170: Loss= 0.000008
# True
# Iter 8171: Loss= 0.000009
# True
# Iter 8172: Loss= 0.000009
# True
# Iter 8173: Loss= 0.000009
# True
# Iter 8174: Loss= 0.000008
# True
# Iter 8175: Loss= 0.000006
# True
# Iter 8176: Loss= 0.000004
# True
# Iter 8177: Loss= 0.000003
# True
# Iter 8178: Loss= 0.000003
# True
# Iter 8179: Loss= 0.000004
# True
# Iter 8180: Loss= 0.000005
# True
# Iter 8181: Loss= 0.000005
# True
# Iter 8182: Loss= 0.000004
# True
# Iter 8183: Loss= 0.000003
# True
# Iter 8184: Loss= 0.000003
# True
# Iter 8185: Loss= 0.000002
# True
# Iter 8186: Loss= 0.000003
# True
# Iter 8187: Loss= 0.000003
# True
# Iter 8188: Loss= 0.000004
# True
# Iter 8189: Loss= 0.000003
# True
# Iter 8190: Loss= 0.000003
# True
# Iter 8191: Loss= 0.000002
# True
# Iter 8192: Loss= 0.000002
# True
# Iter 8193: Loss= 0.000003
# True
# Iter 8194: Loss= 0.000003
# True
# Iter 8195: Loss= 0.000003
# True
# Iter 8196: Loss= 0.000003
# True
# Iter 8197: Loss= 0.000003
# True
# Iter 8198: Loss= 0.000002
# True
# Iter 8199: Loss= 0.000002
# True
# Iter 8200: Loss= 0.000002
# True
# Iter 8201: Loss= 0.000002
# True
# Iter 8202: Loss= 0.000003
# True
# Iter 8203: Loss= 0.000002
# True
# Iter 8204: Loss= 0.000002
# True
# Iter 8205: Loss= 0.000002
# True
# Iter 8206: Loss= 0.000002
# True
# Iter 8207: Loss= 0.000002
# True
# Iter 8208: Loss= 0.000002
# True
# Iter 8209: Loss= 0.000002
# True
# Iter 8210: Loss= 0.000002
# True
# Iter 8211: Loss= 0.000002
# True
# Iter 8212: Loss= 0.000002
# True
# Iter 8213: Loss= 0.000002
# True
# Iter 8214: Loss= 0.000002
# True
# Iter 8215: Loss= 0.000002
# True
# Iter 8216: Loss= 0.000002
# True
# Iter 8217: Loss= 0.000002
# True
# Iter 8218: Loss= 0.000002
# True
# Iter 8219: Loss= 0.000002
# True
# Iter 8220: Loss= 0.000002
# True
# Iter 8221: Loss= 0.000002
# True
# Iter 8222: Loss= 0.000002
# True
# Iter 8223: Loss= 0.000002
# True
# Iter 8224: Loss= 0.000002
# True
# Iter 8225: Loss= 0.000002
# True
# Iter 8226: Loss= 0.000002
# True
# Iter 8227: Loss= 0.000002
# True
# Iter 8228: Loss= 0.000002
# True
# Iter 8229: Loss= 0.000002
# True
# Iter 8230: Loss= 0.000002
# True
# Iter 8231: Loss= 0.000002
# True
# Iter 8232: Loss= 0.000002
# True
# Iter 8233: Loss= 0.000002
# True
# Iter 8234: Loss= 0.000002
# True
# Iter 8235: Loss= 0.000002
# True
# Iter 8236: Loss= 0.000002
# True
# Iter 8237: Loss= 0.000002
# True
# Iter 8238: Loss= 0.000002
# True
# Iter 8239: Loss= 0.000002
# True
# Iter 8240: Loss= 0.000002
# True
# Iter 8241: Loss= 0.000002
# True
# Iter 8242: Loss= 0.000002
# True
# Iter 8243: Loss= 0.000002
# True
# Iter 8244: Loss= 0.000002
# True
# Iter 8245: Loss= 0.000002
# True
# Iter 8246: Loss= 0.000002
# True
# Iter 8247: Loss= 0.000002
# True
# Iter 8248: Loss= 0.000002
# True
# Iter 8249: Loss= 0.000002
# True
# Iter 8250: Loss= 0.000002
# True
# Iter 8251: Loss= 0.000002
# True
# Iter 8252: Loss= 0.000002
# True
# Iter 8253: Loss= 0.000002
# True
# Iter 8254: Loss= 0.000002
# True
# Iter 8255: Loss= 0.000002
# True
# Iter 8256: Loss= 0.000002
# True
# Iter 8257: Loss= 0.000002
# True
# Iter 8258: Loss= 0.000002
# True
# Iter 8259: Loss= 0.000002
# True
# Iter 8260: Loss= 0.000002
# True
# Iter 8261: Loss= 0.000002
# True
# Iter 8262: Loss= 0.000002
# True
# Iter 8263: Loss= 0.000002
# True
# Iter 8264: Loss= 0.000002
# True
# Iter 8265: Loss= 0.000002
# True
# Iter 8266: Loss= 0.000002
# True
# Iter 8267: Loss= 0.000002
# True
# Iter 8268: Loss= 0.000002
# True
# Iter 8269: Loss= 0.000002
# True
# Iter 8270: Loss= 0.000002
# True
# Iter 8271: Loss= 0.000002
# True
# Iter 8272: Loss= 0.000002
# True
# Iter 8273: Loss= 0.000001
# True
# Iter 8274: Loss= 0.000001
# True
# Iter 8275: Loss= 0.000001
# True
# Iter 8276: Loss= 0.000001
# True
# Iter 8277: Loss= 0.000001
# True
# Iter 8278: Loss= 0.000001
# True
# Iter 8279: Loss= 0.000001
# True
# Iter 8280: Loss= 0.000001
# True
# Iter 8281: Loss= 0.000001
# True
# Iter 8282: Loss= 0.000001
# True
# Iter 8283: Loss= 0.000001
# True
# Iter 8284: Loss= 0.000001
# True
# Iter 8285: Loss= 0.000001
# True
# Iter 8286: Loss= 0.000001
# True
# Iter 8287: Loss= 0.000001
# True
# Iter 8288: Loss= 0.000001
# True
# Iter 8289: Loss= 0.000001
# True
# Iter 8290: Loss= 0.000001
# True
# Iter 8291: Loss= 0.000001
# True
# Iter 8292: Loss= 0.000001
# True
# Iter 8293: Loss= 0.000001
# True
# Iter 8294: Loss= 0.000001
# True
# Iter 8295: Loss= 0.000001
# True
# Iter 8296: Loss= 0.000001
# True
# Iter 8297: Loss= 0.000001
# True
# Iter 8298: Loss= 0.000001
# True
# Iter 8299: Loss= 0.000001
# True
# Iter 8300: Loss= 0.000001
# True
# Iter 8301: Loss= 0.000001
# True
# Iter 8302: Loss= 0.000001
# True
# Iter 8303: Loss= 0.000001
# True
# Iter 8304: Loss= 0.000001
# True
# Iter 8305: Loss= 0.000001
# True
# Iter 8306: Loss= 0.000001
# True
# Iter 8307: Loss= 0.000001
# True
# Iter 8308: Loss= 0.000001
# True
# Iter 8309: Loss= 0.000001
# True
# Iter 8310: Loss= 0.000001
# True
# Iter 8311: Loss= 0.000001
# True
# Iter 8312: Loss= 0.000001
# True
# Iter 8313: Loss= 0.000001
# True
# Iter 8314: Loss= 0.000001
# True
# Iter 8315: Loss= 0.000001
# True
# Iter 8316: Loss= 0.000001
# True
# Iter 8317: Loss= 0.000001
# True
# Iter 8318: Loss= 0.000001
# True
# Iter 8319: Loss= 0.000001
# True
# Iter 8320: Loss= 0.000001
# True
# Iter 8321: Loss= 0.000001
# True
# Iter 8322: Loss= 0.000001
# True
# Iter 8323: Loss= 0.000001
# True
# Iter 8324: Loss= 0.000001
# True
# Iter 8325: Loss= 0.000001
# True
# Iter 8326: Loss= 0.000001
# True
# Iter 8327: Loss= 0.000001
# True
# Iter 8328: Loss= 0.000001
# True
# Iter 8329: Loss= 0.000001
# True
# Iter 8330: Loss= 0.000001
# True
# Iter 8331: Loss= 0.000001
# True
# Iter 8332: Loss= 0.000001
# True
# Iter 8333: Loss= 0.000001
# True
# Iter 8334: Loss= 0.000001
# True
# Iter 8335: Loss= 0.000001
# True
# Iter 8336: Loss= 0.000001
# True
# Iter 8337: Loss= 0.000001
# True
# Iter 8338: Loss= 0.000001
# True
# Iter 8339: Loss= 0.000001
# True
# Iter 8340: Loss= 0.000001
# True
# Iter 8341: Loss= 0.000001
# True
# Iter 8342: Loss= 0.000001
# True
# Iter 8343: Loss= 0.000001
# True
# Iter 8344: Loss= 0.000002
# True
# Iter 8345: Loss= 0.000002
# True
# Iter 8346: Loss= 0.000002
# True
# Iter 8347: Loss= 0.000003
# True
# Iter 8348: Loss= 0.000004
# True
# Iter 8349: Loss= 0.000006
# True
# Iter 8350: Loss= 0.000008
# True
# Iter 8351: Loss= 0.000010
# True
# Iter 8352: Loss= 0.000011
# True
# Iter 8353: Loss= 0.000011
# True
# Iter 8354: Loss= 0.000008
# True
# Iter 8355: Loss= 0.000004
# True
# Iter 8356: Loss= 0.000002
# True
# Iter 8357: Loss= 0.000001
# True
# Iter 8358: Loss= 0.000003
# True
# Iter 8359: Loss= 0.000004
# True
# Iter 8360: Loss= 0.000005
# True
# Iter 8361: Loss= 0.000004
# True
# Iter 8362: Loss= 0.000002
# True
# Iter 8363: Loss= 0.000001
# True
# Iter 8364: Loss= 0.000001
# True
# Iter 8365: Loss= 0.000002
# True
# Iter 8366: Loss= 0.000003
# True
# Iter 8367: Loss= 0.000003
# True
# Iter 8368: Loss= 0.000002
# True
# Iter 8369: Loss= 0.000001
# True
# Iter 8370: Loss= 0.000001
# True
# Iter 8371: Loss= 0.000001
# True
# Iter 8372: Loss= 0.000002
# True
# Iter 8373: Loss= 0.000002
# True
# Iter 8374: Loss= 0.000001
# True
# Iter 8375: Loss= 0.000001
# True
# Iter 8376: Loss= 0.000001
# True
# Iter 8377: Loss= 0.000001
# True
# Iter 8378: Loss= 0.000001
# True
# Iter 8379: Loss= 0.000001
# True
# Iter 8380: Loss= 0.000001
# True
# Iter 8381: Loss= 0.000001
# True
# Iter 8382: Loss= 0.000001
# True
# Iter 8383: Loss= 0.000001
# True
# Iter 8384: Loss= 0.000001
# True
# Iter 8385: Loss= 0.000001
# True
# Iter 8386: Loss= 0.000001
# True
# Iter 8387: Loss= 0.000001
# True
# Iter 8388: Loss= 0.000001
# True
# Iter 8389: Loss= 0.000001
# True
# Iter 8390: Loss= 0.000001
# True
# Iter 8391: Loss= 0.000001
# True
# Iter 8392: Loss= 0.000001
# True
# Iter 8393: Loss= 0.000001
# True
# Iter 8394: Loss= 0.000001
# True
# Iter 8395: Loss= 0.000001
# True
# Iter 8396: Loss= 0.000001
# True
# Iter 8397: Loss= 0.000001
# True
# Iter 8398: Loss= 0.000001
# True
# Iter 8399: Loss= 0.000001
# True
# Iter 8400: Loss= 0.000001
# True
# Iter 8401: Loss= 0.000001
# True
# Iter 8402: Loss= 0.000001
# True
# Iter 8403: Loss= 0.000001
# True
# Iter 8404: Loss= 0.000001
# True
# Iter 8405: Loss= 0.000001
# True
# Iter 8406: Loss= 0.000001
# True
# Iter 8407: Loss= 0.000001
# True
# Iter 8408: Loss= 0.000001
# True
# Iter 8409: Loss= 0.000001
# True
# Iter 8410: Loss= 0.000001
# True
# Iter 8411: Loss= 0.000001
# True
# Iter 8412: Loss= 0.000001
# True
# Iter 8413: Loss= 0.000001
# True
# Iter 8414: Loss= 0.000001
# True
# Iter 8415: Loss= 0.000001
# True
# Iter 8416: Loss= 0.000001
# True
# Iter 8417: Loss= 0.000001
# True
# Iter 8418: Loss= 0.000001
# True
# Iter 8419: Loss= 0.000001
# True
# Iter 8420: Loss= 0.000001
# True
# Iter 8421: Loss= 0.000001
# True
# Iter 8422: Loss= 0.000001
# True
# Iter 8423: Loss= 0.000001
# True
# Iter 8424: Loss= 0.000001
# True
# Iter 8425: Loss= 0.000001
# True
# Iter 8426: Loss= 0.000001
# True
# Iter 8427: Loss= 0.000001
# True
# Iter 8428: Loss= 0.000001
# True
# Iter 8429: Loss= 0.000001
# True
# Iter 8430: Loss= 0.000001
# True
# Iter 8431: Loss= 0.000001
# True
# Iter 8432: Loss= 0.000001
# True
# Iter 8433: Loss= 0.000001
# True
# Iter 8434: Loss= 0.000001
# True
# Iter 8435: Loss= 0.000001
# True
# Iter 8436: Loss= 0.000001
# True
# Iter 8437: Loss= 0.000001
# True
# Iter 8438: Loss= 0.000001
# True
# Iter 8439: Loss= 0.000001
# True
# Iter 8440: Loss= 0.000001
# True
# Iter 8441: Loss= 0.000001
# True
# Iter 8442: Loss= 0.000001
# True
# Iter 8443: Loss= 0.000001
# True
# Iter 8444: Loss= 0.000001
# True
# Iter 8445: Loss= 0.000001
# True
# Iter 8446: Loss= 0.000001
# True
# Iter 8447: Loss= 0.000001
# True
# Iter 8448: Loss= 0.000001
# True
# Iter 8449: Loss= 0.000001
# True
# Iter 8450: Loss= 0.000001
# True
# Iter 8451: Loss= 0.000001
# True
# Iter 8452: Loss= 0.000001
# True
# Iter 8453: Loss= 0.000001
# True
# Iter 8454: Loss= 0.000001
# True
# Iter 8455: Loss= 0.000001
# True
# Iter 8456: Loss= 0.000001
# True
# Iter 8457: Loss= 0.000001
# True
# Iter 8458: Loss= 0.000001
# True
# Iter 8459: Loss= 0.000000
# True
# Iter 8460: Loss= 0.000000
# True
# Iter 8461: Loss= 0.000000
# True
# Iter 8462: Loss= 0.000000
# True
# Iter 8463: Loss= 0.000000
# True
# Iter 8464: Loss= 0.000000
# True
# Iter 8465: Loss= 0.000000
# True
# Iter 8466: Loss= 0.000000
# True
# Iter 8467: Loss= 0.000000
# True
# Iter 8468: Loss= 0.000000
# True
# Iter 8469: Loss= 0.000000
# True
# Iter 8470: Loss= 0.000000
# True
# Iter 8471: Loss= 0.000000
# True
# Iter 8472: Loss= 0.000000
# True
# Iter 8473: Loss= 0.000000
# True
# Iter 8474: Loss= 0.000000
# True
# Iter 8475: Loss= 0.000000
# True
# Iter 8476: Loss= 0.000000
# True
# Iter 8477: Loss= 0.000000
# True
# Iter 8478: Loss= 0.000000
# True
# Iter 8479: Loss= 0.000000
# True
# Iter 8480: Loss= 0.000000
# True
# Iter 8481: Loss= 0.000000
# True
# Iter 8482: Loss= 0.000000
# True
# Iter 8483: Loss= 0.000000
# True
# Iter 8484: Loss= 0.000000
# True
# Iter 8485: Loss= 0.000000
# True
# Iter 8486: Loss= 0.000000
# True
# Iter 8487: Loss= 0.000000
# True
# Iter 8488: Loss= 0.000000
# True
# Iter 8489: Loss= 0.000000
# True
# Iter 8490: Loss= 0.000000
# True
# Iter 8491: Loss= 0.000000
# True
# Iter 8492: Loss= 0.000000
# True
# Iter 8493: Loss= 0.000000
# True
# Iter 8494: Loss= 0.000000
# True
# Iter 8495: Loss= 0.000000
# True
# Iter 8496: Loss= 0.000000
# True
# Iter 8497: Loss= 0.000000
# True
# Iter 8498: Loss= 0.000000
# True
# Iter 8499: Loss= 0.000000
# True
# Iter 8500: Loss= 0.000000
# True
# Iter 8501: Loss= 0.000000
# True
# Iter 8502: Loss= 0.000000
# True
# Iter 8503: Loss= 0.000000
# True
# Iter 8504: Loss= 0.000000
# True
# Iter 8505: Loss= 0.000000
# True
# Iter 8506: Loss= 0.000000
# True
# Iter 8507: Loss= 0.000000
# True
# Iter 8508: Loss= 0.000000
# True
# Iter 8509: Loss= 0.000000
# True
# Iter 8510: Loss= 0.000000
# True
# Iter 8511: Loss= 0.000000
# True
# Iter 8512: Loss= 0.000000
# True
# Iter 8513: Loss= 0.000000
# True
# Iter 8514: Loss= 0.000000
# True
# Iter 8515: Loss= 0.000000
# True
# Iter 8516: Loss= 0.000000
# True
# Iter 8517: Loss= 0.000000
# True
# Iter 8518: Loss= 0.000000
# True
# Iter 8519: Loss= 0.000000
# True
# Iter 8520: Loss= 0.000000
# True
# Iter 8521: Loss= 0.000000
# True
# Iter 8522: Loss= 0.000000
# True
# Iter 8523: Loss= 0.000000
# True
# Iter 8524: Loss= 0.000000
# True
# Iter 8525: Loss= 0.000000
# True
# Iter 8526: Loss= 0.000000
# True
# Iter 8527: Loss= 0.000000
# True
# Iter 8528: Loss= 0.000000
# True
# Iter 8529: Loss= 0.000000
# True
# Iter 8530: Loss= 0.000000
# True
# Iter 8531: Loss= 0.000000
# True
# Iter 8532: Loss= 0.000000
# True
# Iter 8533: Loss= 0.000000
# True
# Iter 8534: Loss= 0.000000
# True
# Iter 8535: Loss= 0.000000
# True
# Iter 8536: Loss= 0.000000
# True
# Iter 8537: Loss= 0.000000
# True
# Iter 8538: Loss= 0.000000
# True
# Iter 8539: Loss= 0.000000
# True
# Iter 8540: Loss= 0.000000
# True
# Iter 8541: Loss= 0.000000
# True
# Iter 8542: Loss= 0.000000
# True
# Iter 8543: Loss= 0.000000
# True
# Iter 8544: Loss= 0.000000
# True
# Iter 8545: Loss= 0.000000
# True
# Iter 8546: Loss= 0.000000
# True
# Iter 8547: Loss= 0.000000
# True
# Iter 8548: Loss= 0.000000
# True
# Iter 8549: Loss= 0.000000
# True
# Iter 8550: Loss= 0.000000
# True
# Iter 8551: Loss= 0.000000
# True
# Iter 8552: Loss= 0.000000
# True
# Iter 8553: Loss= 0.000001
# True
# Iter 8554: Loss= 0.000001
# True
# Iter 8555: Loss= 0.000001
# True
# Iter 8556: Loss= 0.000001
# True
# Iter 8557: Loss= 0.000002
# True
# Iter 8558: Loss= 0.000002
# True
# Iter 8559: Loss= 0.000003
# True
# Iter 8560: Loss= 0.000005
# True
# Iter 8561: Loss= 0.000007
# True
# Iter 8562: Loss= 0.000009
# True
# Iter 8563: Loss= 0.000011
# True
# Iter 8564: Loss= 0.000011
# True
# Iter 8565: Loss= 0.000009
# True
# Iter 8566: Loss= 0.000005
# True
# Iter 8567: Loss= 0.000002
# True
# Iter 8568: Loss= 0.000000
# True
# Iter 8569: Loss= 0.000001
# True
# Iter 8570: Loss= 0.000003
# True
# ...
# True
# Iter 9016: Loss= 0.000000
# True
# Iter 9017: Loss= 0.000000
# True
# Iter 9018: Loss= 0.000000
# True
# Iter 9019: Loss= 0.000000
# True
# Iter 9020: Loss= 0.000000
# True
# Iter 9021: Loss= 0.000000
# True
# Iter 9022: Loss= 0.000000
# True
# Iter 9023: Loss= 0.000000
# True
# Iter 9024: Loss= 0.000000
# True
# Iter 9025: Loss= 0.000000
# True
# Iter 9026: Loss= 0.000000
# True
# Iter 9027: Loss= 0.000000
# True
# Iter 9028: Loss= 0.000000
# True
# Iter 9029: Loss= 0.000000
# True
# Iter 9030: Loss= 0.000000
# True
# Iter 9031: Loss= 0.000000
# True
# Iter 9032: Loss= 0.000000
# True
# Iter 9033: Loss= 0.000000
# True
# Iter 9034: Loss= 0.000000
# True
# Iter 9035: Loss= 0.000000
# True
# Iter 9036: Loss= 0.000000
# True
# Iter 9037: Loss= 0.000000
# True
# Iter 9038: Loss= 0.000000
# True
# Iter 9039: Loss= 0.000001
# True
# Iter 9040: Loss= 0.000001
# True
# Iter 9041: Loss= 0.000001
# True
# Iter 9042: Loss= 0.000002
# True
# Iter 9043: Loss= 0.000003
# True
# Iter 9044: Loss= 0.000005
# True
# Iter 9045: Loss= 0.000007
# True
# Iter 9046: Loss= 0.000009
# True
# Iter 9047: Loss= 0.000011
# True
# Iter 9048: Loss= 0.000012
# True
# Iter 9049: Loss= 0.000011
# True
# Iter 9050: Loss= 0.000007
# True
# Iter 9051: Loss= 0.000003
# True
# Iter 9052: Loss= 0.000001
# True
# Iter 9053: Loss= 0.000000
# True
# Iter 9054: Loss= 0.000002
# True
# Iter 9055: Loss= 0.000004
# True
# Iter 9056: Loss= 0.000005
# True
# Iter 9057: Loss= 0.000004
# True
# Iter 9058: Loss= 0.000002
# True
# Iter 9059: Loss= 0.000000
# True
# Iter 9060: Loss= 0.000000
# True
# Iter 9061: Loss= 0.000001
# True
# Iter 9062: Loss= 0.000002
# True
# Iter 9063: Loss= 0.000002
# True
# Iter 9064: Loss= 0.000002
# True
# Iter 9065: Loss= 0.000001
# True
# Iter 9066: Loss= 0.000000
# True
# Iter 9067: Loss= 0.000000
# True
# Iter 9068: Loss= 0.000001
# True
# Iter 9069: Loss= 0.000001
# True
# Iter 9070: Loss= 0.000001
# True
# Iter 9071: Loss= 0.000001
# True
# Iter 9072: Loss= 0.000000
# True
# Iter 9073: Loss= 0.000000
# True
# Iter 9074: Loss= 0.000000
# True
# Iter 9075: Loss= 0.000000
# True
# Iter 9076: Loss= 0.000001
# True
# Iter 9077: Loss= 0.000000
# True
# Iter 9078: Loss= 0.000000
# True
# Iter 9079: Loss= 0.000000
# True
# Iter 9080: Loss= 0.000000
# True
# Iter 9081: Loss= 0.000000
# True
# Iter 9082: Loss= 0.000000
# True
# Iter 9083: Loss= 0.000000
# True
# Iter 9084: Loss= 0.000000
# True
# Iter 9085: Loss= 0.000000
# True
# Iter 9086: Loss= 0.000000
# True
# Iter 9087: Loss= 0.000000
# True
# Iter 9088: Loss= 0.000000
# True
# Iter 9089: Loss= 0.000000
# True
# Iter 9090: Loss= 0.000000
# True
# Iter 9091: Loss= 0.000000
# True
# Iter 9092: Loss= 0.000000
# True
# Iter 9093: Loss= 0.000000
# True
# Iter 9094: Loss= 0.000000
# True
# Iter 9095: Loss= 0.000000
# True
# Iter 9096: Loss= 0.000000
# True
# Iter 9097: Loss= 0.000000
# True
# Iter 9098: Loss= 0.000000
# True
# Iter 9099: Loss= 0.000000
# True
# Iter 9100: Loss= 0.000000
# True
# Iter 9101: Loss= 0.000000
# True
# Iter 9102: Loss= 0.000000
# True
# Iter 9103: Loss= 0.000000
# True
# Iter 9104: Loss= 0.000000
# True
# Iter 9105: Loss= 0.000000
# True
# Iter 9106: Loss= 0.000000
# True
# Iter 9107: Loss= 0.000000
# True
# Iter 9108: Loss= 0.000000
# True
# Iter 9109: Loss= 0.000000
# True
# Iter 9110: Loss= 0.000000
# True
# Iter 9111: Loss= 0.000000
# True
# Iter 9112: Loss= 0.000000
# True
# Iter 9113: Loss= 0.000000
# True
# Iter 9114: Loss= 0.000000
# True
# Iter 9115: Loss= 0.000000
# True
# Iter 9116: Loss= 0.000000
# True
# Iter 9117: Loss= 0.000000
# True
# Iter 9118: Loss= 0.000000
# True
# Iter 9119: Loss= 0.000000
# True
# Iter 9120: Loss= 0.000000
# True
# Iter 9121: Loss= 0.000000
# True
# Iter 9122: Loss= 0.000000
# True
# Iter 9123: Loss= 0.000000
# True
# Iter 9124: Loss= 0.000000
# True
# Iter 9125: Loss= 0.000000
# True
# Iter 9126: Loss= 0.000000
# True
# Iter 9127: Loss= 0.000000
# True
# Iter 9128: Loss= 0.000000
# True
# Iter 9129: Loss= 0.000000
# True
# Iter 9130: Loss= 0.000000
# True
# Iter 9131: Loss= 0.000000
# True
# Iter 9132: Loss= 0.000000
# True
# Iter 9133: Loss= 0.000000
# True
# Iter 9134: Loss= 0.000000
# True
# Iter 9135: Loss= 0.000000
# True
# Iter 9136: Loss= 0.000000
# True
# Iter 9137: Loss= 0.000000
# True
# Iter 9138: Loss= 0.000000
# True
# Iter 9139: Loss= 0.000000
# True
# Iter 9140: Loss= 0.000000
# True
# Iter 9141: Loss= 0.000000
# True
# Iter 9142: Loss= 0.000000
# True
# Iter 9143: Loss= 0.000000
# True
# Iter 9144: Loss= 0.000000
# True
# Iter 9145: Loss= 0.000000
# True
# Iter 9146: Loss= 0.000000
# True
# Iter 9147: Loss= 0.000000
# True
# Iter 9148: Loss= 0.000000
# True
# Iter 9149: Loss= 0.000000
# True
# Iter 9150: Loss= 0.000000
# True
# Iter 9151: Loss= 0.000000
# True
# Iter 9152: Loss= 0.000000
# True
# Iter 9153: Loss= 0.000000
# True
# Iter 9154: Loss= 0.000000
# True
# Iter 9155: Loss= 0.000000
# True
# Iter 9156: Loss= 0.000000
# True
# Iter 9157: Loss= 0.000000
# True
# Iter 9158: Loss= 0.000000
# True
# Iter 9159: Loss= 0.000000
# True
# Iter 9160: Loss= 0.000000
# True
# Iter 9161: Loss= 0.000000
# True
# Iter 9162: Loss= 0.000000
# True
# Iter 9163: Loss= 0.000000
# True
# Iter 9164: Loss= 0.000000
# True
# Iter 9165: Loss= 0.000000
# True
# Iter 9166: Loss= 0.000000
# True
# Iter 9167: Loss= 0.000000
# True
# Iter 9168: Loss= 0.000000
# True
# Iter 9169: Loss= 0.000000
# True
# Iter 9170: Loss= 0.000000
# True
# Iter 9171: Loss= 0.000000
# True
# Iter 9172: Loss= 0.000000
# True
# Iter 9173: Loss= 0.000000
# True
# Iter 9174: Loss= 0.000000
# True
# Iter 9175: Loss= 0.000000
# True
# Iter 9176: Loss= 0.000000
# True
# Iter 9177: Loss= 0.000000
# True
# Iter 9178: Loss= 0.000000
# True
# Iter 9179: Loss= 0.000000
# True
# Iter 9180: Loss= 0.000000
# True
# Iter 9181: Loss= 0.000000
# True
# Iter 9182: Loss= 0.000000
# True
# Iter 9183: Loss= 0.000000
# True
# Iter 9184: Loss= 0.000000
# True
# Iter 9185: Loss= 0.000000
# True
# Iter 9186: Loss= 0.000000
# True
# Iter 9187: Loss= 0.000000
# True
# Iter 9188: Loss= 0.000000
# True
# Iter 9189: Loss= 0.000000
# True
# Iter 9190: Loss= 0.000000
# True
# Iter 9191: Loss= 0.000000
# True
# Iter 9192: Loss= 0.000000
# True
# Iter 9193: Loss= 0.000000
# True
# Iter 9194: Loss= 0.000000
# True
# Iter 9195: Loss= 0.000000
# True
# Iter 9196: Loss= 0.000000
# True
# Iter 9197: Loss= 0.000000
# True
# Iter 9198: Loss= 0.000000
# True
# Iter 9199: Loss= 0.000000
# True
# Iter 9200: Loss= 0.000000
# True
# Iter 9201: Loss= 0.000000
# True
# Iter 9202: Loss= 0.000000
# True
# Iter 9203: Loss= 0.000000
# True
# Iter 9204: Loss= 0.000000
# True
# Iter 9205: Loss= 0.000000
# True
# Iter 9206: Loss= 0.000000
# True
# Iter 9207: Loss= 0.000000
# True
# Iter 9208: Loss= 0.000000
# True
# Iter 9209: Loss= 0.000000
# True
# Iter 9210: Loss= 0.000000
# True
# Iter 9211: Loss= 0.000000
# True
# Iter 9212: Loss= 0.000000
# True
# Iter 9213: Loss= 0.000000
# True
# Iter 9214: Loss= 0.000000
# True
# Iter 9215: Loss= 0.000000
# True
# Iter 9216: Loss= 0.000000
# True
# Iter 9217: Loss= 0.000000
# True
# Iter 9218: Loss= 0.000000
# True
# Iter 9219: Loss= 0.000000
# True
# Iter 9220: Loss= 0.000000
# True
# Iter 9221: Loss= 0.000000
# True
# Iter 9222: Loss= 0.000000
# True
# Iter 9223: Loss= 0.000000
# True
# Iter 9224: Loss= 0.000000
# True
# Iter 9225: Loss= 0.000000
# True
# Iter 9226: Loss= 0.000000
# True
# Iter 9227: Loss= 0.000000
# True
# Iter 9228: Loss= 0.000000
# True
# Iter 9229: Loss= 0.000000
# True
# Iter 9230: Loss= 0.000000
# True
# Iter 9231: Loss= 0.000001
# True
# Iter 9232: Loss= 0.000001
# True
# Iter 9233: Loss= 0.000001
# True
# Iter 9234: Loss= 0.000002
# True
# Iter 9235: Loss= 0.000003
# True
# Iter 9236: Loss= 0.000004
# True
# Iter 9237: Loss= 0.000006
# True
# Iter 9238: Loss= 0.000008
# True
# Iter 9239: Loss= 0.000010
# True
# Iter 9240: Loss= 0.000011
# True
# Iter 9241: Loss= 0.000011
# True
# Iter 9242: Loss= 0.000009
# True
# Iter 9243: Loss= 0.000005
# True
# Iter 9244: Loss= 0.000002
# True
# Iter 9245: Loss= 0.000000
# True
# Iter 9246: Loss= 0.000001
# True
# Iter 9247: Loss= 0.000002
# True
# Iter 9248: Loss= 0.000004
# True
# Iter 9249: Loss= 0.000004
# True
# Iter 9250: Loss= 0.000003
# True
# Iter 9251: Loss= 0.000001
# True
# Iter 9252: Loss= 0.000000
# True
# Iter 9253: Loss= 0.000000
# True
# Iter 9254: Loss= 0.000001
# True
# Iter 9255: Loss= 0.000002
# True
# Iter 9256: Loss= 0.000002
# True
# Iter 9257: Loss= 0.000001
# True
# Iter 9258: Loss= 0.000001
# True
# Iter 9259: Loss= 0.000000
# True
# Iter 9260: Loss= 0.000000
# True
# Iter 9261: Loss= 0.000001
# True
# Iter 9262: Loss= 0.000001
# True
# Iter 9263: Loss= 0.000001
# True
# Iter 9264: Loss= 0.000001
# True
# Iter 9265: Loss= 0.000000
# True
# Iter 9266: Loss= 0.000000
# True
# Iter 9267: Loss= 0.000000
# True
# Iter 9268: Loss= 0.000000
# True
# Iter 9269: Loss= 0.000001
# True
# Iter 9270: Loss= 0.000000
# True
# Iter 9271: Loss= 0.000000
# True
# Iter 9272: Loss= 0.000000
# True
# Iter 9273: Loss= 0.000000
# True
# Iter 9274: Loss= 0.000000
# True
# Iter 9275: Loss= 0.000000
# True
# Iter 9276: Loss= 0.000000
# True
# Iter 9277: Loss= 0.000000
# True
# Iter 9278: Loss= 0.000000
# True
# Iter 9279: Loss= 0.000000
# True
# Iter 9280: Loss= 0.000000
# True
# Iter 9281: Loss= 0.000000
# True
# Iter 9282: Loss= 0.000000
# True
# Iter 9283: Loss= 0.000000
# True
# Iter 9284: Loss= 0.000000
# True
# Iter 9285: Loss= 0.000000
# True
# Iter 9286: Loss= 0.000000
# True
# Iter 9287: Loss= 0.000000
# True
# Iter 9288: Loss= 0.000000
# True
# Iter 9289: Loss= 0.000000
# True
# Iter 9290: Loss= 0.000000
# True
# Iter 9291: Loss= 0.000000
# True
# Iter 9292: Loss= 0.000000
# True
# Iter 9293: Loss= 0.000000
# True
# Iter 9294: Loss= 0.000000
# True
# Iter 9295: Loss= 0.000000
# True
# Iter 9296: Loss= 0.000000
# True
# Iter 9297: Loss= 0.000000
# True
# Iter 9298: Loss= 0.000000
# True
# Iter 9299: Loss= 0.000000
# True
# Iter 9300: Loss= 0.000000
# True
# Iter 9301: Loss= 0.000000
# True
# Iter 9302: Loss= 0.000000
# True
# Iter 9303: Loss= 0.000000
# True
# Iter 9304: Loss= 0.000000
# True
# Iter 9305: Loss= 0.000000
# True
# Iter 9306: Loss= 0.000000
# True
# Iter 9307: Loss= 0.000000
# True
# Iter 9308: Loss= 0.000000
# True
# Iter 9309: Loss= 0.000000
# True
# Iter 9310: Loss= 0.000000
# True
# Iter 9311: Loss= 0.000000
# True
# Iter 9312: Loss= 0.000000
# True
# Iter 9313: Loss= 0.000000
# True
# Iter 9314: Loss= 0.000000
# True
# Iter 9315: Loss= 0.000000
# True
# Iter 9316: Loss= 0.000000
# True
# Iter 9317: Loss= 0.000000
# True
# Iter 9318: Loss= 0.000000
# True
# Iter 9319: Loss= 0.000000
# True
# Iter 9320: Loss= 0.000000
# True
# Iter 9321: Loss= 0.000000
# True
# Iter 9322: Loss= 0.000000
# True
# Iter 9323: Loss= 0.000000
# True
# Iter 9324: Loss= 0.000000
# True
# Iter 9325: Loss= 0.000000
# True
# Iter 9326: Loss= 0.000000
# True
# Iter 9327: Loss= 0.000000
# True
# Iter 9328: Loss= 0.000000
# True
# Iter 9329: Loss= 0.000000
# True
# Iter 9330: Loss= 0.000000
# True
# Iter 9331: Loss= 0.000000
# True
# Iter 9332: Loss= 0.000000
# True
# Iter 9333: Loss= 0.000000
# True
# Iter 9334: Loss= 0.000000
# True
# Iter 9335: Loss= 0.000000
# True
# Iter 9336: Loss= 0.000000
# True
# Iter 9337: Loss= 0.000000
# True
# Iter 9338: Loss= 0.000000
# True
# Iter 9339: Loss= 0.000000
# True
# Iter 9340: Loss= 0.000000
# True
# Iter 9341: Loss= 0.000000
# True
# Iter 9342: Loss= 0.000000
# True
# Iter 9343: Loss= 0.000000
# True
# Iter 9344: Loss= 0.000000
# True
# Iter 9345: Loss= 0.000000
# True
# Iter 9346: Loss= 0.000000
# True
# Iter 9347: Loss= 0.000000
# True
# Iter 9348: Loss= 0.000000
# True
# Iter 9349: Loss= 0.000000
# True
# Iter 9350: Loss= 0.000000
# True
# Iter 9351: Loss= 0.000000
# True
# Iter 9352: Loss= 0.000000
# True
# Iter 9353: Loss= 0.000000
# True
# Iter 9354: Loss= 0.000000
# True
# Iter 9355: Loss= 0.000000
# True
# Iter 9356: Loss= 0.000000
# True
# Iter 9357: Loss= 0.000000
# True
# Iter 9358: Loss= 0.000000
# True
# Iter 9359: Loss= 0.000000
# True
# Iter 9360: Loss= 0.000000
# True
# Iter 9361: Loss= 0.000000
# True
# Iter 9362: Loss= 0.000000
# True
# Iter 9363: Loss= 0.000000
# True
# Iter 9364: Loss= 0.000000
# True
# Iter 9365: Loss= 0.000000
# True
# Iter 9366: Loss= 0.000000
# True
# Iter 9367: Loss= 0.000000
# True
# Iter 9368: Loss= 0.000000
# True
# Iter 9369: Loss= 0.000000
# True
# Iter 9370: Loss= 0.000000
# True
# Iter 9371: Loss= 0.000000
# True
# Iter 9372: Loss= 0.000000
# True
# Iter 9373: Loss= 0.000000
# True
# Iter 9374: Loss= 0.000000
# True
# Iter 9375: Loss= 0.000000
# True
# Iter 9376: Loss= 0.000000
# True
# Iter 9377: Loss= 0.000000
# True
# Iter 9378: Loss= 0.000000
# True
# Iter 9379: Loss= 0.000000
# True
# Iter 9380: Loss= 0.000000
# True
# Iter 9381: Loss= 0.000000
# True
# Iter 9382: Loss= 0.000000
# True
# Iter 9383: Loss= 0.000000
# True
# Iter 9384: Loss= 0.000000
# True
# Iter 9385: Loss= 0.000000
# True
# Iter 9386: Loss= 0.000000
# True
# Iter 9387: Loss= 0.000000
# True
# Iter 9388: Loss= 0.000000
# True
# Iter 9389: Loss= 0.000000
# True
# Iter 9390: Loss= 0.000000
# True
# Iter 9391: Loss= 0.000000
# True
# Iter 9392: Loss= 0.000000
# True
# Iter 9393: Loss= 0.000000
# True
# Iter 9394: Loss= 0.000000
# True
# Iter 9395: Loss= 0.000000
# True
# Iter 9396: Loss= 0.000000
# True
# Iter 9397: Loss= 0.000000
# True
# Iter 9398: Loss= 0.000000
# True
# Iter 9399: Loss= 0.000000
# True
# Iter 9400: Loss= 0.000000
# True
# Iter 9401: Loss= 0.000000
# True
# Iter 9402: Loss= 0.000000
# True
# Iter 9403: Loss= 0.000000
# True
# Iter 9404: Loss= 0.000000
# True
# Iter 9405: Loss= 0.000000
# True
# Iter 9406: Loss= 0.000000
# True
# Iter 9407: Loss= 0.000000
# True
# Iter 9408: Loss= 0.000000
# True
# Iter 9409: Loss= 0.000000
# True
# Iter 9410: Loss= 0.000000
# True
# Iter 9411: Loss= 0.000000
# True
# Iter 9412: Loss= 0.000000
# True
# Iter 9413: Loss= 0.000000
# True
# Iter 9414: Loss= 0.000000
# True
# Iter 9415: Loss= 0.000000
# True
# Iter 9416: Loss= 0.000000
# True
# Iter 9417: Loss= 0.000000
# True
# Iter 9418: Loss= 0.000000
# True
# Iter 9419: Loss= 0.000000
# True
# Iter 9420: Loss= 0.000000
# True
# Iter 9421: Loss= 0.000000
# True
# Iter 9422: Loss= 0.000000
# True
# Iter 9423: Loss= 0.000000
# True
# Iter 9424: Loss= 0.000000
# True
# Iter 9425: Loss= 0.000000
# True
# Iter 9426: Loss= 0.000001
# True
# Iter 9427: Loss= 0.000001
# True
# Iter 9428: Loss= 0.000002
# True
# Iter 9429: Loss= 0.000003
# True
# Iter 9430: Loss= 0.000005
# True
# Iter 9431: Loss= 0.000007
# True
# Iter 9432: Loss= 0.000010
# True
# Iter 9433: Loss= 0.000014
# True
# Iter 9434: Loss= 0.000016
# True
# Iter 9435: Loss= 0.000016
# True
# Iter 9436: Loss= 0.000013
# True
# Iter 9437: Loss= 0.000006
# True
# Iter 9438: Loss= 0.000001
# True
# Iter 9439: Loss= 0.000000
# True
# Iter 9440: Loss= 0.000003
# True
# Iter 9441: Loss= 0.000006
# True
# Iter 9442: Loss= 0.000007
# True
# Iter 9443: Loss= 0.000005
# True
# Iter 9444: Loss= 0.000002
# True
# Iter 9445: Loss= 0.000000
# True
# Iter 9446: Loss= 0.000001
# True
# Iter 9447: Loss= 0.000003
# True
# Iter 9448: Loss= 0.000004
# True
# Iter 9449: Loss= 0.000003
# True
# Iter 9450: Loss= 0.000001
# True
# Iter 9451: Loss= 0.000000
# True
# Iter 9452: Loss= 0.000001
# True
# Iter 9453: Loss= 0.000002
# True
# Iter 9454: Loss= 0.000002
# True
# Iter 9455: Loss= 0.000001
# True
# Iter 9456: Loss= 0.000000
# True
# Iter 9457: Loss= 0.000000
# True
# Iter 9458: Loss= 0.000000
# True
# Iter 9459: Loss= 0.000001
# True
# Iter 9460: Loss= 0.000001
# True
# Iter 9461: Loss= 0.000001
# True
# Iter 9462: Loss= 0.000000
# True
# Iter 9463: Loss= 0.000000
# True
# Iter 9464: Loss= 0.000000
# True
# Iter 9465: Loss= 0.000001
# True
# Iter 9466: Loss= 0.000001
# True
# Iter 9467: Loss= 0.000000
# True
# Iter 9468: Loss= 0.000000
# True
# Iter 9469: Loss= 0.000000
# True
# Iter 9470: Loss= 0.000000
# True
# Iter 9471: Loss= 0.000000
# True
# Iter 9472: Loss= 0.000000
# True
# Iter 9473: Loss= 0.000000
# True
# Iter 9474: Loss= 0.000000
# True
# Iter 9475: Loss= 0.000000
# True
# Iter 9476: Loss= 0.000000
# True
# Iter 9477: Loss= 0.000000
# True
# Iter 9478: Loss= 0.000000
# True
# Iter 9479: Loss= 0.000000
# True
# Iter 9480: Loss= 0.000000
# True
# Iter 9481: Loss= 0.000000
# True
# Iter 9482: Loss= 0.000000
# True
# Iter 9483: Loss= 0.000000
# True
# Iter 9484: Loss= 0.000000
# True
# Iter 9485: Loss= 0.000000
# True
# Iter 9486: Loss= 0.000000
# True
# Iter 9487: Loss= 0.000000
# True
# Iter 9488: Loss= 0.000000
# True
# Iter 9489: Loss= 0.000000
# True
# Iter 9490: Loss= 0.000000
# True
# Iter 9491: Loss= 0.000000
# True
# Iter 9492: Loss= 0.000000
# True
# Iter 9493: Loss= 0.000000
# True
# Iter 9494: Loss= 0.000000
# True
# Iter 9495: Loss= 0.000000
# True
# Iter 9496: Loss= 0.000000
# True
# Iter 9497: Loss= 0.000000
# True
# Iter 9498: Loss= 0.000000
# True
# Iter 9499: Loss= 0.000000
# True
# Iter 9500: Loss= 0.000000
# True
# Iter 9501: Loss= 0.000000
# True
# Iter 9502: Loss= 0.000000
# True
# Iter 9503: Loss= 0.000000
# True
# Iter 9504: Loss= 0.000000
# True
# Iter 9505: Loss= 0.000000
# True
# Iter 9506: Loss= 0.000000
# True
# Iter 9507: Loss= 0.000000
# True
# Iter 9508: Loss= 0.000000
# True
# Iter 9509: Loss= 0.000000
# True
# Iter 9510: Loss= 0.000000
# True
# Iter 9511: Loss= 0.000000
# True
# Iter 9512: Loss= 0.000000
# True
# Iter 9513: Loss= 0.000000
# True
# Iter 9514: Loss= 0.000000
# True
# Iter 9515: Loss= 0.000000
# True
# Iter 9516: Loss= 0.000000
# True
# Iter 9517: Loss= 0.000000
# True
# Iter 9518: Loss= 0.000000
# True
# Iter 9519: Loss= 0.000000
# True
# Iter 9520: Loss= 0.000000
# Optimization Finished!
# The resulted symplectic matrix is:
# tensor([[ 9.9998e-01,  3.0000e+00,  1.0000e+00, -2.2590e-05],
#         [ 2.0000e+00,  4.0000e+00, -2.5000e+00,  1.5000e+00],
#         [-1.1685e-05, -4.9949e-06, -2.0000e+00,  9.9999e-01],
#         [ 1.8839e-05,  2.2375e-05,  1.5000e+00, -4.9997e-01]],
#        grad_fn=<MmBackward>)

# %%
plt.plot(losses_1,'r')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# #Mini Batch

# %%
batch_losses = []

from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
data = TensorDataset(torch.tensor(V).float(),torch.tensor(y).float())
dataloader =  DataLoader(data,batch_size = 32, shuffle=True)
def main(train_dl, loss_func=nn.MSELoss()):
    model = test_Model(input_size).to(device)
    model.train()

    non_symp_params, log_symp_params = get_parameters(model)
    #optim = torch.optim.Adam(non_symp_params, args.lr)
    optim_symp = torch.optim.Adam(log_symp_params, lr=5e-3)
    # using decreasing learning rate lr=lr*0.997**epoch
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optim_symp, gamma=0.997)

    for epoch in range(3000):
        train_losses = []
        for step, (x, y) in enumerate(train_dl):

            prediction = model(x.to(device))

            loss = loss_func(prediction, y.to(device))
            loss.backward()

            #optim.step()
            if optim_symp:
                optim_symp.step()

            #optim.zero_grad()
            if optim_symp:
                optim_symp.zero_grad()
            train_losses.append(loss.item())
        
        scheduler.step()
        batch_losses.append(np.mean(train_losses))
        print(model.symp.is_diffeo)
        print("Iter {}: Loss= {:.6f}".format(epoch, np.mean(train_losses)))
        #print(model.symp.A)
        if loss <= 1e-10:
          break

    print("Optimization Finished!")
    model.eval()
    print(model.symp.A)

main(dataloader)
# Out:
# True
# Iter 0: Loss= 3.753836
# True
# Iter 1: Loss= 2.877573
# True
# Iter 2: Loss= 1.950688
# True
# Iter 3: Loss= 1.082762
# True
# Iter 4: Loss= 0.626403
# True
# Iter 5: Loss= 0.538769
# True
# Iter 6: Loss= 0.537559
# True
# Iter 7: Loss= 0.529924
# True
# Iter 8: Loss= 0.541496
# True
# Iter 9: Loss= 0.519879
# True
# Iter 10: Loss= 0.525294
# True
# Iter 11: Loss= 0.528031
# True
# Iter 12: Loss= 0.523165
# True
# Iter 13: Loss= 0.512084
# True
# Iter 14: Loss= 0.502718
# True
# Iter 15: Loss= 0.499750
# True
# Iter 16: Loss= 0.489729
# True
# Iter 17: Loss= 0.487028
# True
# Iter 18: Loss= 0.477567
# True
# Iter 19: Loss= 0.470211
# True
# Iter 20: Loss= 0.448242
# True
# Iter 21: Loss= 0.446815
# True
# Iter 22: Loss= 0.433585
# True
# Iter 23: Loss= 0.427838
# True
# Iter 24: Loss= 0.415636
# True
# Iter 25: Loss= 0.402886
# True
# Iter 26: Loss= 0.390589
# True
# Iter 27: Loss= 0.383043
# True
# Iter 28: Loss= 0.369955
# True
# Iter 29: Loss= 0.358073
# True
# Iter 30: Loss= 0.356347
# True
# Iter 31: Loss= 0.338407
# True
# Iter 32: Loss= 0.325247
# True
# Iter 33: Loss= 0.320833
# True
# Iter 34: Loss= 0.311350
# True
# Iter 35: Loss= 0.304013
# True
# Iter 36: Loss= 0.298464
# True
# Iter 37: Loss= 0.290052
# True
# Iter 38: Loss= 0.286494
# True
# Iter 39: Loss= 0.277769
# True
# Iter 40: Loss= 0.278411
# True
# Iter 41: Loss= 0.268184
# True
# Iter 42: Loss= 0.258779
# True
# Iter 43: Loss= 0.254892
# True
# Iter 44: Loss= 0.252794
# True
# Iter 45: Loss= 0.252310
# True
# Iter 46: Loss= 0.245701
# True
# Iter 47: Loss= 0.240221
# True
# Iter 48: Loss= 0.240762
# True
# Iter 49: Loss= 0.237450
# True
# Iter 50: Loss= 0.230675
# True
# Iter 51: Loss= 0.226295
# True
# Iter 52: Loss= 0.225464
# True
# Iter 53: Loss= 0.222988
# True
# Iter 54: Loss= 0.220766
# True
# Iter 55: Loss= 0.217659
# True
# Iter 56: Loss= 0.216961
# True
# Iter 57: Loss= 0.218123
# True
# Iter 58: Loss= 0.210350
# True
# Iter 59: Loss= 0.206438
# True
# Iter 60: Loss= 0.208175
# True
# Iter 61: Loss= 0.204901
# True
# Iter 62: Loss= 0.202685
# True
# Iter 63: Loss= 0.201555
# True
# Iter 64: Loss= 0.199313
# True
# Iter 65: Loss= 0.199990
# True
# Iter 66: Loss= 0.196084
# True
# Iter 67: Loss= 0.194820
# True
# Iter 68: Loss= 0.195533
# True
# Iter 69: Loss= 0.191811
# True
# Iter 70: Loss= 0.190346
# True
# Iter 71: Loss= 0.190252
# True
# Iter 72: Loss= 0.184892
# True
# Iter 73: Loss= 0.183994
# True
# Iter 74: Loss= 0.181123
# True
# Iter 75: Loss= 0.181155
# True
# Iter 76: Loss= 0.179798
# True
# Iter 77: Loss= 0.177970
# True
# Iter 78: Loss= 0.178520
# True
# Iter 79: Loss= 0.178621
# True
# Iter 80: Loss= 0.176576
# True
# Iter 81: Loss= 0.174655
# True
# Iter 82: Loss= 0.170701
# True
# Iter 83: Loss= 0.168465
# True
# Iter 84: Loss= 0.168248
# True
# Iter 85: Loss= 0.172484
# True
# Iter 86: Loss= 0.166751
# True
# Iter 87: Loss= 0.165514
# True
# Iter 88: Loss= 0.163668
# True
# Iter 89: Loss= 0.164677
# True
# Iter 90: Loss= 0.161583
# True
# Iter 91: Loss= 0.158702
# True
# Iter 92: Loss= 0.160069
# True
# Iter 93: Loss= 0.155039
# True
# Iter 94: Loss= 0.155332
# True
# Iter 95: Loss= 0.156386
# True
# Iter 96: Loss= 0.152391
# True
# Iter 97: Loss= 0.153499
# True
# Iter 98: Loss= 0.152331
# True
# Iter 99: Loss= 0.149718
# True
# Iter 100: Loss= 0.148294
# True
# Iter 101: Loss= 0.147271
# True
# Iter 102: Loss= 0.146501
# True
# Iter 103: Loss= 0.144608
# True
# Iter 104: Loss= 0.145519
# True
# Iter 105: Loss= 0.144393
# True
# Iter 106: Loss= 0.141519
# True
# Iter 107: Loss= 0.140919
# True
# Iter 108: Loss= 0.139031
# True
# Iter 109: Loss= 0.142603
# True
# Iter 110: Loss= 0.136945
# True
# Iter 111: Loss= 0.135563
# True
# Iter 112: Loss= 0.134619
# True
# Iter 113: Loss= 0.134057
# True
# Iter 114: Loss= 0.133094
# True
# Iter 115: Loss= 0.135047
# True
# Iter 116: Loss= 0.131967
# True
# Iter 117: Loss= 0.128944
# True
# Iter 118: Loss= 0.133033
# True
# Iter 119: Loss= 0.128880
# True
# Iter 120: Loss= 0.127579
# True
# Iter 121: Loss= 0.126650
# True
# Iter 122: Loss= 0.126397
# True
# Iter 123: Loss= 0.124574
# True
# Iter 124: Loss= 0.122687
# True
# Iter 125: Loss= 0.121670
# True
# Iter 126: Loss= 0.121581
# True
# Iter 127: Loss= 0.121165
# True
# Iter 128: Loss= 0.120123
# True
# Iter 129: Loss= 0.117946
# True
# Iter 130: Loss= 0.119818
# True
# Iter 131: Loss= 0.117066
# True
# Iter 132: Loss= 0.115932
# True
# Iter 133: Loss= 0.116691
# True
# Iter 134: Loss= 0.113690
# True
# Iter 135: Loss= 0.112975
# True
# Iter 136: Loss= 0.113108
# True
# Iter 137: Loss= 0.111290
# True
# Iter 138: Loss= 0.111548
# True
# Iter 139: Loss= 0.111952
# True
# Iter 140: Loss= 0.110025
# True
# Iter 141: Loss= 0.111139
# True
# Iter 142: Loss= 0.110265
# True
# Iter 143: Loss= 0.106494
# True
# Iter 144: Loss= 0.106764
# True
# Iter 145: Loss= 0.106937
# True
# Iter 146: Loss= 0.104692
# True
# Iter 147: Loss= 0.102498
# True
# Iter 148: Loss= 0.104495
# True
# Iter 149: Loss= 0.102063
# True
# Iter 150: Loss= 0.102235
# True
# Iter 151: Loss= 0.101296
# True
# Iter 152: Loss= 0.100986
# True
# Iter 153: Loss= 0.100749
# True
# Iter 154: Loss= 0.100667
# True
# Iter 155: Loss= 0.097931
# True
# Iter 156: Loss= 0.097703
# True
# Iter 157: Loss= 0.097583
# True
# Iter 158: Loss= 0.094958
# True
# Iter 159: Loss= 0.095622
# True
# Iter 160: Loss= 0.094188
# True
# Iter 161: Loss= 0.094173
# True
# Iter 162: Loss= 0.092163
# True
# Iter 163: Loss= 0.092225
# True
# Iter 164: Loss= 0.091242
# True
# Iter 165: Loss= 0.090482
# True
# Iter 166: Loss= 0.090307
# True
# Iter 167: Loss= 0.089566
# True
# Iter 168: Loss= 0.088321
# True
# Iter 169: Loss= 0.088227
# True
# Iter 170: Loss= 0.088991
# True
# Iter 171: Loss= 0.089309
# True
# Iter 172: Loss= 0.085678
# True
# Iter 173: Loss= 0.085874
# True
# Iter 174: Loss= 0.085806
# True
# Iter 175: Loss= 0.084418
# True
# Iter 176: Loss= 0.083413
# True
# Iter 177: Loss= 0.083964
# True
# Iter 178: Loss= 0.083710
# True
# Iter 179: Loss= 0.082558
# True
# Iter 180: Loss= 0.082979
# True
# Iter 181: Loss= 0.082541
# True
# Iter 182: Loss= 0.080664
# True
# Iter 183: Loss= 0.080365
# True
# Iter 184: Loss= 0.078430
# True
# Iter 185: Loss= 0.078935
# True
# Iter 186: Loss= 0.079308
# True
# Iter 187: Loss= 0.077342
# True
# Iter 188: Loss= 0.076838
# True
# Iter 189: Loss= 0.076563
# True
# Iter 190: Loss= 0.075948
# True
# Iter 191: Loss= 0.077047
# True
# Iter 192: Loss= 0.075087
# True
# Iter 193: Loss= 0.074363
# True
# Iter 194: Loss= 0.074329
# True
# Iter 195: Loss= 0.073035
# True
# Iter 196: Loss= 0.072857
# True
# Iter 197: Loss= 0.072356
# True
# Iter 198: Loss= 0.070582
# True
# Iter 199: Loss= 0.072106
# True
# Iter 200: Loss= 0.071238
# True
# Iter 201: Loss= 0.070992
# True
# Iter 202: Loss= 0.070941
# True
# Iter 203: Loss= 0.068807
# True
# Iter 204: Loss= 0.069092
# True
# Iter 205: Loss= 0.068368
# True
# Iter 206: Loss= 0.067734
# True
# Iter 207: Loss= 0.066724
# True
# Iter 208: Loss= 0.066382
# True
# Iter 209: Loss= 0.065942
# True
# Iter 210: Loss= 0.064768
# True
# Iter 211: Loss= 0.065888
# True
# Iter 212: Loss= 0.064077
# True
# Iter 213: Loss= 0.064005
# True
# Iter 214: Loss= 0.063130
# True
# Iter 215: Loss= 0.063915
# True
# Iter 216: Loss= 0.064087
# True
# Iter 217: Loss= 0.063547
# True
# Iter 218: Loss= 0.062812
# True
# Iter 219: Loss= 0.062968
# True
# Iter 220: Loss= 0.061746
# True
# Iter 221: Loss= 0.060876
# True
# Iter 222: Loss= 0.060562
# True
# Iter 223: Loss= 0.059237
# True
# Iter 224: Loss= 0.059940
# True
# Iter 225: Loss= 0.058542
# True
# Iter 226: Loss= 0.058900
# True
# Iter 227: Loss= 0.059513
# True
# Iter 228: Loss= 0.057449
# True
# Iter 229: Loss= 0.057277
# True
# Iter 230: Loss= 0.056272
# True
# Iter 231: Loss= 0.056439
# True
# Iter 232: Loss= 0.057015
# True
# Iter 233: Loss= 0.056517
# True
# Iter 234: Loss= 0.055158
# True
# Iter 235: Loss= 0.054892
# True
# Iter 236: Loss= 0.054094
# True
# Iter 237: Loss= 0.054452
# True
# Iter 238: Loss= 0.054123
# True
# Iter 239: Loss= 0.053809
# True
# Iter 240: Loss= 0.052303
# True
# Iter 241: Loss= 0.052925
# True
# Iter 242: Loss= 0.051729
# True
# Iter 243: Loss= 0.051844
# True
# Iter 244: Loss= 0.052050
# True
# Iter 245: Loss= 0.051657
# True
# Iter 246: Loss= 0.051876
# True
# Iter 247: Loss= 0.050103
# True
# Iter 248: Loss= 0.050118
# True
# Iter 249: Loss= 0.050802
# True
# Iter 250: Loss= 0.048949
# True
# Iter 251: Loss= 0.049267
# True
# Iter 252: Loss= 0.048605
# True
# Iter 253: Loss= 0.049067
# True
# Iter 254: Loss= 0.047830
# True
# Iter 255: Loss= 0.048343
# True
# Iter 256: Loss= 0.047839
# True
# Iter 257: Loss= 0.047296
# True
# Iter 258: Loss= 0.046675
# True
# Iter 259: Loss= 0.046049
# True
# Iter 260: Loss= 0.046361
# True
# Iter 261: Loss= 0.045764
# True
# Iter 262: Loss= 0.045610
# True
# Iter 263: Loss= 0.045889
# True
# Iter 264: Loss= 0.044963
# True
# Iter 265: Loss= 0.044737
# True
# Iter 266: Loss= 0.044398
# True
# Iter 267: Loss= 0.043645
# True
# Iter 268: Loss= 0.043992
# True
# Iter 269: Loss= 0.042674
# True
# Iter 270: Loss= 0.043142
# True
# Iter 271: Loss= 0.043448
# True
# Iter 272: Loss= 0.042599
# True
# Iter 273: Loss= 0.042409
# True
# Iter 274: Loss= 0.041427
# True
# Iter 275: Loss= 0.041766
# True
# Iter 276: Loss= 0.041418
# True
# Iter 277: Loss= 0.041002
# True
# Iter 278: Loss= 0.040253
# True
# Iter 279: Loss= 0.040506
# True
# Iter 280: Loss= 0.039998
# True
# Iter 281: Loss= 0.040259
# True
# Iter 282: Loss= 0.039442
# True
# Iter 283: Loss= 0.038814
# True
# Iter 284: Loss= 0.038472
# True
# Iter 285: Loss= 0.038514
# True
# Iter 286: Loss= 0.038808
# True
# Iter 287: Loss= 0.038261
# True
# Iter 288: Loss= 0.037913
# True
# Iter 289: Loss= 0.037266
# True
# Iter 290: Loss= 0.037324
# True
# Iter 291: Loss= 0.037151
# True
# Iter 292: Loss= 0.037483
# True
# Iter 293: Loss= 0.036472
# True
# Iter 294: Loss= 0.036329
# True
# Iter 295: Loss= 0.035787
# True
# Iter 296: Loss= 0.035329
# True
# Iter 297: Loss= 0.035009
# True
# Iter 298: Loss= 0.034959
# True
# Iter 299: Loss= 0.034637
# True
# Iter 300: Loss= 0.034306
# True
# Iter 301: Loss= 0.034379
# True
# Iter 302: Loss= 0.034214
# True
# Iter 303: Loss= 0.034729
# True
# Iter 304: Loss= 0.034120
# True
# Iter 305: Loss= 0.033591
# True
# Iter 306: Loss= 0.034513
# True
# Iter 307: Loss= 0.033311
# True
# Iter 308: Loss= 0.033418
# True
# Iter 309: Loss= 0.032749
# True
# Iter 310: Loss= 0.032549
# True
# Iter 311: Loss= 0.032350
# True
# Iter 312: Loss= 0.032425
# True
# Iter 313: Loss= 0.031517
# True
# Iter 314: Loss= 0.031318
# True
# Iter 315: Loss= 0.031367
# True
# Iter 316: Loss= 0.031389
# True
# Iter 317: Loss= 0.030515
# True
# Iter 318: Loss= 0.030370
# True
# Iter 319: Loss= 0.030742
# True
# Iter 320: Loss= 0.030432
# True
# Iter 321: Loss= 0.030092
# True
# Iter 322: Loss= 0.029975
# True
# Iter 323: Loss= 0.029341
# True
# Iter 324: Loss= 0.029749
# True
# Iter 325: Loss= 0.029241
# True
# Iter 326: Loss= 0.029400
# True
# Iter 327: Loss= 0.029268
# True
# Iter 328: Loss= 0.028690
# True
# Iter 329: Loss= 0.028095
# True
# Iter 330: Loss= 0.028548
# True
# Iter 331: Loss= 0.028044
# True
# Iter 332: Loss= 0.027866
# True
# Iter 333: Loss= 0.027284
# True
# Iter 334: Loss= 0.027823
# True
# Iter 335: Loss= 0.027493
# True
# Iter 336: Loss= 0.026775
# True
# Iter 337: Loss= 0.026589
# True
# Iter 338: Loss= 0.026592
# True
# Iter 339: Loss= 0.026939
# True
# Iter 340: Loss= 0.026670
# True
# Iter 341: Loss= 0.025802
# True
# Iter 342: Loss= 0.025752
# True
# Iter 343: Loss= 0.025866
# True
# Iter 344: Loss= 0.025117
# True
# Iter 345: Loss= 0.025011
# True
# Iter 346: Loss= 0.025186
# True
# Iter 347: Loss= 0.025106
# True
# Iter 348: Loss= 0.024772
# True
# Iter 349: Loss= 0.024439
# True
# Iter 350: Loss= 0.024361
# True
# Iter 351: Loss= 0.024188
# True
# Iter 352: Loss= 0.024008
# True
# Iter 353: Loss= 0.024451
# True
# Iter 354: Loss= 0.024089
# True
# Iter 355: Loss= 0.023433
# True
# Iter 356: Loss= 0.023718
# True
# Iter 357: Loss= 0.023435
# True
# Iter 358: Loss= 0.022966
# True
# Iter 359: Loss= 0.023320
# True
# Iter 360: Loss= 0.023270
# True
# Iter 361: Loss= 0.022746
# True
# Iter 362: Loss= 0.022409
# True
# Iter 363: Loss= 0.022852
# True
# Iter 364: Loss= 0.021984
# True
# Iter 365: Loss= 0.022339
# True
# Iter 366: Loss= 0.022080
# True
# Iter 367: Loss= 0.021520
# True
# Iter 368: Loss= 0.021960
# True
# Iter 369: Loss= 0.021628
# True
# Iter 370: Loss= 0.021538
# True
# Iter 371: Loss= 0.021441
# True
# Iter 372: Loss= 0.020807
# True
# Iter 373: Loss= 0.020836
# True
# Iter 374: Loss= 0.020948
# True
# Iter 375: Loss= 0.020939
# True
# Iter 376: Loss= 0.020476
# True
# Iter 377: Loss= 0.020415
# True
# Iter 378: Loss= 0.020564
# True
# Iter 379: Loss= 0.019823
# True
# Iter 380: Loss= 0.019866
# True
# Iter 381: Loss= 0.019448
# True
# Iter 382: Loss= 0.019961
# True
# Iter 383: Loss= 0.019448
# True
# Iter 384: Loss= 0.019624
# True
# Iter 385: Loss= 0.018981
# True
# Iter 386: Loss= 0.019238
# True
# Iter 387: Loss= 0.019105
# True
# Iter 388: Loss= 0.018597
# True
# Iter 389: Loss= 0.018940
# True
# Iter 390: Loss= 0.018585
# True
# Iter 391: Loss= 0.018653
# True
# Iter 392: Loss= 0.018314
# True
# Iter 393: Loss= 0.018522
# True
# Iter 394: Loss= 0.018034
# True
# Iter 395: Loss= 0.017846
# True
# Iter 396: Loss= 0.017884
# True
# Iter 397: Loss= 0.017483
# True
# Iter 398: Loss= 0.017410
# True
# Iter 399: Loss= 0.017228
# True
# Iter 400: Loss= 0.017162
# True
# Iter 401: Loss= 0.017269
# True
# Iter 402: Loss= 0.016979
# True
# Iter 403: Loss= 0.016969
# True
# Iter 404: Loss= 0.016772
# True
# Iter 405: Loss= 0.016920
# True
# Iter 406: Loss= 0.016908
# True
# Iter 407: Loss= 0.016463
# True
# Iter 408: Loss= 0.016381
# True
# Iter 409: Loss= 0.016114
# True
# Iter 410: Loss= 0.016280
# True
# Iter 411: Loss= 0.015910
# True
# Iter 412: Loss= 0.016077
# True
# Iter 413: Loss= 0.015945
# True
# Iter 414: Loss= 0.015479
# True
# Iter 415: Loss= 0.015946
# True
# Iter 416: Loss= 0.015236
# True
# Iter 417: Loss= 0.015415
# True
# Iter 418: Loss= 0.015157
# True
# Iter 419: Loss= 0.015219
# True
# Iter 420: Loss= 0.014916
# True
# Iter 421: Loss= 0.014888
# True
# Iter 422: Loss= 0.014865
# True
# Iter 423: Loss= 0.014879
# True
# Iter 424: Loss= 0.014648
# True
# Iter 425: Loss= 0.014587
# True
# Iter 426: Loss= 0.014375
# True
# Iter 427: Loss= 0.014261
# True
# Iter 428: Loss= 0.014135
# True
# Iter 429: Loss= 0.013846
# True
# Iter 430: Loss= 0.013905
# True
# Iter 431: Loss= 0.013920
# True
# Iter 432: Loss= 0.013703
# True
# Iter 433: Loss= 0.013756
# True
# Iter 434: Loss= 0.013320
# True
# Iter 435: Loss= 0.013644
# True
# Iter 436: Loss= 0.013351
# True
# Iter 437: Loss= 0.013245
# True
# Iter 438: Loss= 0.013201
# True
# Iter 439: Loss= 0.012952
# True
# Iter 440: Loss= 0.013099
# True
# Iter 441: Loss= 0.012970
# True
# Iter 442: Loss= 0.013070
# True
# Iter 443: Loss= 0.012564
# True
# Iter 444: Loss= 0.012678
# True
# Iter 445: Loss= 0.012524
# True
# Iter 446: Loss= 0.012428
# True
# Iter 447: Loss= 0.012468
# True
# Iter 448: Loss= 0.012342
# True
# Iter 449: Loss= 0.012138
# True
# Iter 450: Loss= 0.012074
# True
# Iter 451: Loss= 0.012209
# True
# Iter 452: Loss= 0.012188
# True
# Iter 453: Loss= 0.011866
# True
# Iter 454: Loss= 0.011612
# True
# Iter 455: Loss= 0.011612
# True
# Iter 456: Loss= 0.011550
# True
# Iter 457: Loss= 0.011482
# True
# Iter 458: Loss= 0.011534
# True
# Iter 459: Loss= 0.011434
# True
# Iter 460: Loss= 0.011401
# True
# Iter 461: Loss= 0.011380
# True
# Iter 462: Loss= 0.011112
# True
# Iter 463: Loss= 0.010940
# True
# Iter 464: Loss= 0.010917
# True
# Iter 465: Loss= 0.010888
# True
# Iter 466: Loss= 0.010634
# True
# Iter 467: Loss= 0.010676
# True
# Iter 468: Loss= 0.010536
# True
# Iter 469: Loss= 0.010572
# True
# Iter 470: Loss= 0.010389
# True
# Iter 471: Loss= 0.010337
# True
# Iter 472: Loss= 0.010362
# True
# Iter 473: Loss= 0.010267
# True
# Iter 474: Loss= 0.010122
# True
# Iter 475: Loss= 0.009960
# True
# Iter 476: Loss= 0.009935
# True
# Iter 477: Loss= 0.010176
# True
# Iter 478: Loss= 0.009992
# True
# Iter 479: Loss= 0.010061
# True
# Iter 480: Loss= 0.009813
# True
# Iter 481: Loss= 0.009522
# True
# Iter 482: Loss= 0.009825
# True
# Iter 483: Loss= 0.009448
# True
# Iter 484: Loss= 0.009376
# True
# Iter 485: Loss= 0.009353
# True
# Iter 486: Loss= 0.009386
# True
# Iter 487: Loss= 0.009152
# True
# Iter 488: Loss= 0.009099
# True
# Iter 489: Loss= 0.008995
# True
# Iter 490: Loss= 0.009260
# True
# Iter 491: Loss= 0.009122
# True
# Iter 492: Loss= 0.008919
# True
# Iter 493: Loss= 0.008837
# True
# Iter 494: Loss= 0.008698
# True
# Iter 495: Loss= 0.008578
# True
# Iter 496: Loss= 0.008545
# True
# Iter 497: Loss= 0.008454
# True
# Iter 498: Loss= 0.008571
# True
# Iter 499: Loss= 0.008400
# True
# Iter 500: Loss= 0.008509
# True
# Iter 501: Loss= 0.008344
# True
# Iter 502: Loss= 0.008238
# True
# Iter 503: Loss= 0.008232
# True
# Iter 504: Loss= 0.008132
# True
# Iter 505: Loss= 0.008178
# True
# Iter 506: Loss= 0.007962
# True
# Iter 507: Loss= 0.007926
# True
# Iter 508: Loss= 0.007955
# True
# Iter 509: Loss= 0.007839
# True
# Iter 510: Loss= 0.007792
# True
# Iter 511: Loss= 0.007726
# True
# Iter 512: Loss= 0.007665
# True
# Iter 513: Loss= 0.007699
# True
# Iter 514: Loss= 0.007601
# True
# Iter 515: Loss= 0.007480
# True
# Iter 516: Loss= 0.007545
# True
# Iter 517: Loss= 0.007325
# True
# Iter 518: Loss= 0.007413
# True
# Iter 519: Loss= 0.007270
# True
# Iter 520: Loss= 0.007307
# True
# Iter 521: Loss= 0.007147
# True
# Iter 522: Loss= 0.007252
# True
# Iter 523: Loss= 0.007156
# True
# Iter 524: Loss= 0.007060
# True
# Iter 525: Loss= 0.006962
# True
# Iter 526: Loss= 0.006920
# True
# Iter 527: Loss= 0.006870
# True
# Iter 528: Loss= 0.006898
# True
# Iter 529: Loss= 0.006761
# True
# Iter 530: Loss= 0.006757
# True
# Iter 531: Loss= 0.006766
# True
# Iter 532: Loss= 0.006602
# True
# Iter 533: Loss= 0.006652
# True
# Iter 534: Loss= 0.006695
# True
# Iter 535: Loss= 0.006489
# True
# Iter 536: Loss= 0.006500
# True
# Iter 537: Loss= 0.006466
# True
# Iter 538: Loss= 0.006276
# True
# Iter 539: Loss= 0.006272
# True
# Iter 540: Loss= 0.006364
# True
# Iter 541: Loss= 0.006212
# True
# Iter 542: Loss= 0.006126
# True
# Iter 543: Loss= 0.006079
# True
# Iter 544: Loss= 0.006048
# True
# Iter 545: Loss= 0.006077
# True
# Iter 546: Loss= 0.005995
# True
# Iter 547: Loss= 0.005969
# True
# Iter 548: Loss= 0.005958
# True
# Iter 549: Loss= 0.005886
# True
# Iter 550: Loss= 0.005835
# True
# Iter 551: Loss= 0.005761
# True
# Iter 552: Loss= 0.005746
# True
# Iter 553: Loss= 0.005648
# True
# Iter 554: Loss= 0.005781
# True
# Iter 555: Loss= 0.005587
# True
# Iter 556: Loss= 0.005563
# True
# Iter 557: Loss= 0.005574
# True
# Iter 558: Loss= 0.005443
# True
# Iter 559: Loss= 0.005457
# True
# Iter 560: Loss= 0.005377
# True
# Iter 561: Loss= 0.005410
# True
# Iter 562: Loss= 0.005405
# True
# Iter 563: Loss= 0.005333
# True
# Iter 564: Loss= 0.005283
# True
# Iter 565: Loss= 0.005198
# True
# Iter 566: Loss= 0.005152
# True
# Iter 567: Loss= 0.005118
# True
# Iter 568: Loss= 0.005246
# True
# Iter 569: Loss= 0.005177
# True
# Iter 570: Loss= 0.005166
# True
# Iter 571: Loss= 0.005017
# True
# Iter 572: Loss= 0.004915
# True
# Iter 573: Loss= 0.004865
# True
# Iter 574: Loss= 0.004809
# True
# Iter 575: Loss= 0.004926
# True
# Iter 576: Loss= 0.004793
# True
# Iter 577: Loss= 0.004724
# True
# Iter 578: Loss= 0.004958
# True
# Iter 579: Loss= 0.004737
# True
# Iter 580: Loss= 0.004648
# True
# Iter 581: Loss= 0.004593
# True
# Iter 582: Loss= 0.004692
# True
# Iter 583: Loss= 0.004645
# True
# Iter 584: Loss= 0.004492
# True
# Iter 585: Loss= 0.004490
# True
# Iter 586: Loss= 0.004525
# True
# Iter 587: Loss= 0.004396
# True
# Iter 588: Loss= 0.004381
# True
# Iter 589: Loss= 0.004297
# True
# Iter 590: Loss= 0.004289
# True
# Iter 591: Loss= 0.004311
# True
# Iter 592: Loss= 0.004216
# True
# Iter 593: Loss= 0.004201
# True
# Iter 594: Loss= 0.004168
# True
# Iter 595: Loss= 0.004148
# True
# Iter 596: Loss= 0.004124
# True
# Iter 597: Loss= 0.004053
# True
# Iter 598: Loss= 0.004107
# True
# Iter 599: Loss= 0.004047
# True
# Iter 600: Loss= 0.003985
# True
# Iter 601: Loss= 0.004025
# True
# Iter 602: Loss= 0.003885
# True
# Iter 603: Loss= 0.003980
# True
# Iter 604: Loss= 0.003919
# True
# Iter 605: Loss= 0.003800
# True
# Iter 606: Loss= 0.003791
# True
# Iter 607: Loss= 0.003868
# True
# Iter 608: Loss= 0.003762
# True
# Iter 609: Loss= 0.003702
# True
# Iter 610: Loss= 0.003737
# True
# Iter 611: Loss= 0.003745
# True
# Iter 612: Loss= 0.003636
# True
# Iter 613: Loss= 0.003616
# True
# Iter 614: Loss= 0.003612
# True
# Iter 615: Loss= 0.003602
# True
# Iter 616: Loss= 0.003528
# True
# Iter 617: Loss= 0.003491
# True
# Iter 618: Loss= 0.003485
# True
# Iter 619: Loss= 0.003557
# True
# Iter 620: Loss= 0.003525
# True
# Iter 621: Loss= 0.003446
# True
# Iter 622: Loss= 0.003395
# True
# Iter 623: Loss= 0.003297
# True
# Iter 624: Loss= 0.003350
# True
# Iter 625: Loss= 0.003337
# True
# Iter 626: Loss= 0.003283
# True
# Iter 627: Loss= 0.003270
# True
# Iter 628: Loss= 0.003267
# True
# Iter 629: Loss= 0.003190
# True
# Iter 630: Loss= 0.003173
# True
# Iter 631: Loss= 0.003136
# True
# Iter 632: Loss= 0.003123
# True
# Iter 633: Loss= 0.003100
# True
# Iter 634: Loss= 0.003069
# True
# Iter 635: Loss= 0.003013
# True
# Iter 636: Loss= 0.003050
# True
# Iter 637: Loss= 0.003032
# True
# Iter 638: Loss= 0.002995
# True
# Iter 639: Loss= 0.002953
# True
# Iter 640: Loss= 0.002937
# True
# Iter 641: Loss= 0.003007
# True
# Iter 642: Loss= 0.002927
# True
# Iter 643: Loss= 0.002829
# True
# Iter 644: Loss= 0.002899
# True
# Iter 645: Loss= 0.002793
# True
# Iter 646: Loss= 0.002796
# True
# Iter 647: Loss= 0.002785
# True
# Iter 648: Loss= 0.002775
# True
# Iter 649: Loss= 0.002734
# True
# Iter 650: Loss= 0.002786
# True
# Iter 651: Loss= 0.002736
# True
# Iter 652: Loss= 0.002723
# True
# Iter 653: Loss= 0.002673
# True
# Iter 654: Loss= 0.002615
# True
# Iter 655: Loss= 0.002603
# True
# Iter 656: Loss= 0.002585
# True
# Iter 657: Loss= 0.002593
# True
# Iter 658: Loss= 0.002559
# True
# Iter 659: Loss= 0.002593
# True
# Iter 660: Loss= 0.002496
# True
# Iter 661: Loss= 0.002536
# True
# Iter 662: Loss= 0.002453
# True
# Iter 663: Loss= 0.002477
# True
# Iter 664: Loss= 0.002415
# True
# Iter 665: Loss= 0.002494
# True
# Iter 666: Loss= 0.002398
# True
# Iter 667: Loss= 0.002369
# True
# Iter 668: Loss= 0.002372
# True
# Iter 669: Loss= 0.002327
# True
# Iter 670: Loss= 0.002294
# True
# Iter 671: Loss= 0.002353
# True
# Iter 672: Loss= 0.002242
# True
# Iter 673: Loss= 0.002255
# True
# Iter 674: Loss= 0.002231
# True
# Iter 675: Loss= 0.002246
# True
# Iter 676: Loss= 0.002221
# True
# Iter 677: Loss= 0.002166
# True
# Iter 678: Loss= 0.002206
# True
# Iter 679: Loss= 0.002140
# True
# Iter 680: Loss= 0.002128
# True
# Iter 681: Loss= 0.002148
# True
# Iter 682: Loss= 0.002133
# True
# Iter 683: Loss= 0.002129
# True
# Iter 684: Loss= 0.002056
# True
# Iter 685: Loss= 0.002080
# True
# Iter 686: Loss= 0.002041
# True
# Iter 687: Loss= 0.002081
# True
# Iter 688: Loss= 0.001996
# True
# Iter 689: Loss= 0.001964
# True
# Iter 690: Loss= 0.001948
# True
# Iter 691: Loss= 0.001979
# True
# Iter 692: Loss= 0.001922
# True
# Iter 693: Loss= 0.001901
# True
# Iter 694: Loss= 0.001896
# True
# Iter 695: Loss= 0.001885
# True
# Iter 696: Loss= 0.001856
# True
# Iter 697: Loss= 0.001889
# True
# Iter 698: Loss= 0.001867
# True
# Iter 699: Loss= 0.001811
# True
# Iter 700: Loss= 0.001810
# True
# Iter 701: Loss= 0.001772
# True
# Iter 702: Loss= 0.001759
# True
# Iter 703: Loss= 0.001785
# True
# Iter 704: Loss= 0.001774
# True
# Iter 705: Loss= 0.001773
# True
# Iter 706: Loss= 0.001718
# True
# Iter 707: Loss= 0.001700
# True
# Iter 708: Loss= 0.001691
# True
# Iter 709: Loss= 0.001675
# True
# Iter 710: Loss= 0.001635
# True
# Iter 711: Loss= 0.001667
# True
# Iter 712: Loss= 0.001634
# True
# Iter 713: Loss= 0.001626
# True
# Iter 714: Loss= 0.001612
# True
# Iter 715: Loss= 0.001590
# True
# Iter 716: Loss= 0.001581
# True
# Iter 717: Loss= 0.001603
# True
# Iter 718: Loss= 0.001576
# True
# Iter 719: Loss= 0.001533
# True
# Iter 720: Loss= 0.001508
# True
# Iter 721: Loss= 0.001521
# True
# Iter 722: Loss= 0.001517
# True
# Iter 723: Loss= 0.001499
# True
# Iter 724: Loss= 0.001496
# True
# Iter 725: Loss= 0.001482
# True
# Iter 726: Loss= 0.001472
# True
# Iter 727: Loss= 0.001436
# True
# Iter 728: Loss= 0.001425
# True
# Iter 729: Loss= 0.001418
# True
# Iter 730: Loss= 0.001396
# True
# Iter 731: Loss= 0.001400
# True
# Iter 732: Loss= 0.001384
# True
# Iter 733: Loss= 0.001391
# True
# Iter 734: Loss= 0.001363
# True
# Iter 735: Loss= 0.001362
# True
# Iter 736: Loss= 0.001345
# True
# Iter 737: Loss= 0.001320
# True
# Iter 738: Loss= 0.001328
# True
# Iter 739: Loss= 0.001327
# True
# Iter 740: Loss= 0.001290
# True
# Iter 741: Loss= 0.001298
# True
# Iter 742: Loss= 0.001251
# True
# Iter 743: Loss= 0.001244
# True
# Iter 744: Loss= 0.001262
# True
# Iter 745: Loss= 0.001245
# True
# Iter 746: Loss= 0.001228
# True
# Iter 747: Loss= 0.001228
# True
# Iter 748: Loss= 0.001197
# True
# Iter 749: Loss= 0.001184
# True
# Iter 750: Loss= 0.001200
# True
# Iter 751: Loss= 0.001171
# True
# Iter 752: Loss= 0.001156
# True
# Iter 753: Loss= 0.001152
# True
# Iter 754: Loss= 0.001128
# True
# Iter 755: Loss= 0.001128
# True
# Iter 756: Loss= 0.001113
# True
# Iter 757: Loss= 0.001126
# True
# Iter 758: Loss= 0.001101
# True
# Iter 759: Loss= 0.001094
# True
# Iter 760: Loss= 0.001104
# True
# Iter 761: Loss= 0.001081
# True
# Iter 762: Loss= 0.001069
# True
# Iter 763: Loss= 0.001046
# True
# Iter 764: Loss= 0.001037
# True
# Iter 765: Loss= 0.001022
# True
# Iter 766: Loss= 0.001017
# True
# Iter 767: Loss= 0.001008
# True
# Iter 768: Loss= 0.001003
# True
# Iter 769: Loss= 0.001011
# True
# Iter 770: Loss= 0.000989
# True
# Iter 771: Loss= 0.000980
# True
# Iter 772: Loss= 0.000967
# True
# Iter 773: Loss= 0.000973
# True
# Iter 774: Loss= 0.000963
# True
# Iter 775: Loss= 0.000959
# True
# Iter 776: Loss= 0.000952
# True
# Iter 777: Loss= 0.000939
# True
# Iter 778: Loss= 0.000926
# True
# Iter 779: Loss= 0.000908
# True
# Iter 780: Loss= 0.000907
# True
# Iter 781: Loss= 0.000901
# True
# Iter 782: Loss= 0.000887
# True
# Iter 783: Loss= 0.000873
# True
# Iter 784: Loss= 0.000871
# True
# Iter 785: Loss= 0.000857
# True
# Iter 786: Loss= 0.000849
# True
# Iter 787: Loss= 0.000863
# True
# Iter 788: Loss= 0.000840
# True
# Iter 789: Loss= 0.000834
# True
# Iter 790: Loss= 0.000828
# True
# Iter 791: Loss= 0.000832
# True
# Iter 792: Loss= 0.000827
# True
# Iter 793: Loss= 0.000822
# True
# Iter 794: Loss= 0.000792
# True
# Iter 795: Loss= 0.000794
# True
# Iter 796: Loss= 0.000786
# True
# Iter 797: Loss= 0.000762
# True
# Iter 798: Loss= 0.000783
# True
# Iter 799: Loss= 0.000755
# True
# Iter 800: Loss= 0.000758
# True
# Iter 801: Loss= 0.000759
# True
# Iter 802: Loss= 0.000739
# True
# Iter 803: Loss= 0.000726
# True
# Iter 804: Loss= 0.000730
# True
# Iter 805: Loss= 0.000710
# True
# Iter 806: Loss= 0.000712
# True
# Iter 807: Loss= 0.000730
# True
# Iter 808: Loss= 0.000699
# True
# Iter 809: Loss= 0.000691
# True
# Iter 810: Loss= 0.000686
# True
# Iter 811: Loss= 0.000689
# True
# Iter 812: Loss= 0.000680
# True
# Iter 813: Loss= 0.000682
# True
# Iter 814: Loss= 0.000655
# True
# Iter 815: Loss= 0.000653
# True
# Iter 816: Loss= 0.000637
# True
# Iter 817: Loss= 0.000634
# True
# Iter 818: Loss= 0.000630
# True
# Iter 819: Loss= 0.000626
# True
# Iter 820: Loss= 0.000617
# True
# Iter 821: Loss= 0.000618
# True
# Iter 822: Loss= 0.000613
# True
# Iter 823: Loss= 0.000619
# True
# Iter 824: Loss= 0.000599
# True
# Iter 825: Loss= 0.000598
# True
# Iter 826: Loss= 0.000580
# True
# Iter 827: Loss= 0.000582
# True
# Iter 828: Loss= 0.000584
# True
# Iter 829: Loss= 0.000570
# True
# Iter 830: Loss= 0.000596
# True
# Iter 831: Loss= 0.000562
# True
# Iter 832: Loss= 0.000548
# True
# Iter 833: Loss= 0.000551
# True
# Iter 834: Loss= 0.000539
# True
# Iter 835: Loss= 0.000532
# True
# Iter 836: Loss= 0.000535
# True
# Iter 837: Loss= 0.000521
# True
# Iter 838: Loss= 0.000519
# True
# Iter 839: Loss= 0.000515
# True
# Iter 840: Loss= 0.000511
# True
# Iter 841: Loss= 0.000511
# True
# Iter 842: Loss= 0.000505
# True
# Iter 843: Loss= 0.000491
# True
# Iter 844: Loss= 0.000491
# True
# Iter 845: Loss= 0.000500
# True
# Iter 846: Loss= 0.000478
# True
# Iter 847: Loss= 0.000475
# True
# Iter 848: Loss= 0.000471
# True
# Iter 849: Loss= 0.000469
# True
# Iter 850: Loss= 0.000467
# True
# Iter 851: Loss= 0.000464
# True
# Iter 852: Loss= 0.000451
# True
# Iter 853: Loss= 0.000443
# True
# Iter 854: Loss= 0.000442
# True
# Iter 855: Loss= 0.000435
# True
# Iter 856: Loss= 0.000432
# True
# Iter 857: Loss= 0.000444
# True
# Iter 858: Loss= 0.000425
# True
# Iter 859: Loss= 0.000417
# True
# Iter 860: Loss= 0.000425
# True
# Iter 861: Loss= 0.000409
# True
# Iter 862: Loss= 0.000413
# True
# Iter 863: Loss= 0.000407
# True
# Iter 864: Loss= 0.000425
# True
# Iter 865: Loss= 0.000397
# True
# Iter 866: Loss= 0.000395
# True
# Iter 867: Loss= 0.000391
# True
# Iter 868: Loss= 0.000395
# True
# Iter 869: Loss= 0.000376
# True
# Iter 870: Loss= 0.000378
# True
# Iter 871: Loss= 0.000370
# True
# Iter 872: Loss= 0.000374
# True
# Iter 873: Loss= 0.000361
# True
# Iter 874: Loss= 0.000363
# True
# Iter 875: Loss= 0.000363
# True
# Iter 876: Loss= 0.000354
# True
# Iter 877: Loss= 0.000350
# True
# Iter 878: Loss= 0.000342
# True
# Iter 879: Loss= 0.000344
# True
# Iter 880: Loss= 0.000340
# True
# Iter 881: Loss= 0.000333
# True
# Iter 882: Loss= 0.000334
# True
# Iter 883: Loss= 0.000328
# True
# Iter 884: Loss= 0.000332
# True
# Iter 885: Loss= 0.000318
# True
# Iter 886: Loss= 0.000320
# True
# Iter 887: Loss= 0.000313
# True
# Iter 888: Loss= 0.000309
# True
# Iter 889: Loss= 0.000308
# True
# Iter 890: Loss= 0.000309
# True
# Iter 891: Loss= 0.000301
# True
# Iter 892: Loss= 0.000301
# True
# Iter 893: Loss= 0.000294
# True
# Iter 894: Loss= 0.000292
# True
# Iter 895: Loss= 0.000286
# True
# Iter 896: Loss= 0.000283
# True
# Iter 897: Loss= 0.000287
# True
# Iter 898: Loss= 0.000282
# True
# Iter 899: Loss= 0.000280
# True
# Iter 900: Loss= 0.000275
# True
# Iter 901: Loss= 0.000269
# True
# Iter 902: Loss= 0.000267
# True
# Iter 903: Loss= 0.000263
# True
# Iter 904: Loss= 0.000263
# True
# Iter 905: Loss= 0.000261
# True
# Iter 906: Loss= 0.000261
# True
# Iter 907: Loss= 0.000254
# True
# Iter 908: Loss= 0.000252
# True
# Iter 909: Loss= 0.000249
# True
# Iter 910: Loss= 0.000258
# True
# Iter 911: Loss= 0.000247
# True
# Iter 912: Loss= 0.000243
# True
# Iter 913: Loss= 0.000242
# True
# Iter 914: Loss= 0.000240
# True
# Iter 915: Loss= 0.000235
# True
# Iter 916: Loss= 0.000233
# True
# Iter 917: Loss= 0.000229
# True
# Iter 918: Loss= 0.000228
# True
# Iter 919: Loss= 0.000230
# True
# Iter 920: Loss= 0.000221
# True
# Iter 921: Loss= 0.000215
# True
# Iter 922: Loss= 0.000223
# True
# Iter 923: Loss= 0.000214
# True
# Iter 924: Loss= 0.000216
# True
# Iter 925: Loss= 0.000210
# True
# Iter 926: Loss= 0.000208
# True
# Iter 927: Loss= 0.000207
# True
# Iter 928: Loss= 0.000206
# True
# Iter 929: Loss= 0.000200
# True
# Iter 930: Loss= 0.000198
# True
# Iter 931: Loss= 0.000195
# True
# Iter 932: Loss= 0.000194
# True
# Iter 933: Loss= 0.000191
# True
# Iter 934: Loss= 0.000187
# True
# Iter 935: Loss= 0.000192
# True
# Iter 936: Loss= 0.000184
# True
# Iter 937: Loss= 0.000183
# True
# Iter 938: Loss= 0.000179
# True
# Iter 939: Loss= 0.000177
# True
# Iter 940: Loss= 0.000177
# True
# Iter 941: Loss= 0.000174
# True
# Iter 942: Loss= 0.000172
# True
# Iter 943: Loss= 0.000168
# True
# Iter 944: Loss= 0.000167
# True
# Iter 945: Loss= 0.000167
# True
# Iter 946: Loss= 0.000164
# True
# Iter 947: Loss= 0.000160
# True
# Iter 948: Loss= 0.000160
# True
# Iter 949: Loss= 0.000159
# True
# Iter 950: Loss= 0.000157
# True
# Iter 951: Loss= 0.000153
# True
# Iter 952: Loss= 0.000153
# True
# Iter 953: Loss= 0.000153
# True
# Iter 954: Loss= 0.000150
# True
# Iter 955: Loss= 0.000147
# True
# Iter 956: Loss= 0.000146
# True
# Iter 957: Loss= 0.000142
# True
# Iter 958: Loss= 0.000143
# True
# Iter 959: Loss= 0.000139
# True
# Iter 960: Loss= 0.000140
# True
# Iter 961: Loss= 0.000136
# True
# Iter 962: Loss= 0.000134
# True
# Iter 963: Loss= 0.000138
# True
# Iter 964: Loss= 0.000130
# True
# Iter 965: Loss= 0.000131
# True
# Iter 966: Loss= 0.000128
# True
# Iter 967: Loss= 0.000128
# True
# Iter 968: Loss= 0.000124
# True
# Iter 969: Loss= 0.000124
# True
# Iter 970: Loss= 0.000122
# True
# Iter 971: Loss= 0.000124
# True
# Iter 972: Loss= 0.000120
# True
# Iter 973: Loss= 0.000117
# True
# Iter 974: Loss= 0.000118
# True
# Iter 975: Loss= 0.000115
# True
# Iter 976: Loss= 0.000116
# True
# Iter 977: Loss= 0.000112
# True
# Iter 978: Loss= 0.000111
# True
# Iter 979: Loss= 0.000109
# True
# Iter 980: Loss= 0.000107
# True
# Iter 981: Loss= 0.000106
# True
# Iter 982: Loss= 0.000105
# True
# Iter 983: Loss= 0.000102
# True
# Iter 984: Loss= 0.000107
# True
# Iter 985: Loss= 0.000101
# True
# Iter 986: Loss= 0.000099
# True
# Iter 987: Loss= 0.000098
# True
# Iter 988: Loss= 0.000095
# True
# Iter 989: Loss= 0.000096
# True
# Iter 990: Loss= 0.000093
# True
# Iter 991: Loss= 0.000094
# True
# Iter 992: Loss= 0.000092
# True
# Iter 993: Loss= 0.000090
# True
# Iter 994: Loss= 0.000089
# True
# Iter 995: Loss= 0.000086
# True
# Iter 996: Loss= 0.000090
# True
# Iter 997: Loss= 0.000087
# True
# Iter 998: Loss= 0.000084
# True
# Iter 999: Loss= 0.000085
# True
# Iter 1000: Loss= 0.000083
# True
# Iter 1001: Loss= 0.000081
# True
# Iter 1002: Loss= 0.000079
# True
# Iter 1003: Loss= 0.000079
# True
# Iter 1004: Loss= 0.000078
# True
# Iter 1005: Loss= 0.000075
# True
# Iter 1006: Loss= 0.000075
# True
# Iter 1007: Loss= 0.000075
# True
# Iter 1008: Loss= 0.000073
# True
# Iter 1009: Loss= 0.000071
# True
# Iter 1010: Loss= 0.000071
# True
# Iter 1011: Loss= 0.000072
# True
# Iter 1012: Loss= 0.000069
# True
# Iter 1013: Loss= 0.000068
# True
# Iter 1014: Loss= 0.000068
# True
# Iter 1015: Loss= 0.000067
# True
# Iter 1016: Loss= 0.000066
# True
# Iter 1017: Loss= 0.000064
# True
# Iter 1018: Loss= 0.000064
# True
# Iter 1019: Loss= 0.000063
# True
# Iter 1020: Loss= 0.000063
# True
# Iter 1021: Loss= 0.000062
# True
# Iter 1022: Loss= 0.000060
# True
# Iter 1023: Loss= 0.000059
# True
# Iter 1024: Loss= 0.000059
# True
# Iter 1025: Loss= 0.000058
# True
# Iter 1026: Loss= 0.000057
# True
# Iter 1027: Loss= 0.000056
# True
# Iter 1028: Loss= 0.000055
# True
# Iter 1029: Loss= 0.000056
# True
# Iter 1030: Loss= 0.000055
# True
# Iter 1031: Loss= 0.000053
# True
# Iter 1032: Loss= 0.000052
# True
# Iter 1033: Loss= 0.000051
# True
# Iter 1034: Loss= 0.000050
# True
# Iter 1035: Loss= 0.000049
# True
# Iter 1036: Loss= 0.000050
# True
# Iter 1037: Loss= 0.000048
# True
# Iter 1038: Loss= 0.000047
# True
# Iter 1039: Loss= 0.000047
# True
# Iter 1040: Loss= 0.000045
# True
# Iter 1041: Loss= 0.000045
# True
# Iter 1042: Loss= 0.000044
# True
# Iter 1043: Loss= 0.000046
# True
# Iter 1044: Loss= 0.000043
# True
# Iter 1045: Loss= 0.000043
# True
# Iter 1046: Loss= 0.000042
# True
# Iter 1047: Loss= 0.000042
# True
# Iter 1048: Loss= 0.000042
# True
# Iter 1049: Loss= 0.000040
# True
# Iter 1050: Loss= 0.000039
# True
# Iter 1051: Loss= 0.000038
# True
# Iter 1052: Loss= 0.000039
# True
# Iter 1053: Loss= 0.000038
# True
# Iter 1054: Loss= 0.000037
# True
# Iter 1055: Loss= 0.000036
# True
# Iter 1056: Loss= 0.000035
# True
# Iter 1057: Loss= 0.000035
# True
# Iter 1058: Loss= 0.000034
# True
# Iter 1059: Loss= 0.000034
# True
# Iter 1060: Loss= 0.000033
# True
# Iter 1061: Loss= 0.000033
# True
# Iter 1062: Loss= 0.000033
# True
# Iter 1063: Loss= 0.000032
# True
# Iter 1064: Loss= 0.000031
# True
# Iter 1065: Loss= 0.000031
# True
# Iter 1066: Loss= 0.000030
# True
# Iter 1067: Loss= 0.000030
# True
# Iter 1068: Loss= 0.000030
# True
# Iter 1069: Loss= 0.000029
# True
# Iter 1070: Loss= 0.000028
# True
# Iter 1071: Loss= 0.000028
# True
# Iter 1072: Loss= 0.000027
# True
# Iter 1073: Loss= 0.000027
# True
# Iter 1074: Loss= 0.000026
# True
# Iter 1075: Loss= 0.000026
# True
# Iter 1076: Loss= 0.000025
# True
# Iter 1077: Loss= 0.000026
# True
# Iter 1078: Loss= 0.000025
# True
# Iter 1079: Loss= 0.000024
# True
# Iter 1080: Loss= 0.000024
# True
# Iter 1081: Loss= 0.000023
# True
# Iter 1082: Loss= 0.000023
# True
# Iter 1083: Loss= 0.000022
# True
# Iter 1084: Loss= 0.000022
# True
# Iter 1085: Loss= 0.000021
# True
# Iter 1086: Loss= 0.000021
# True
# Iter 1087: Loss= 0.000021
# True
# Iter 1088: Loss= 0.000020
# True
# Iter 1089: Loss= 0.000020
# True
# Iter 1090: Loss= 0.000020
# True
# Iter 1091: Loss= 0.000019
# True
# Iter 1092: Loss= 0.000019
# True
# Iter 1093: Loss= 0.000019
# True
# Iter 1094: Loss= 0.000018
# True
# Iter 1095: Loss= 0.000018
# True
# Iter 1096: Loss= 0.000017
# True
# Iter 1097: Loss= 0.000017
# True
# Iter 1098: Loss= 0.000017
# True
# Iter 1099: Loss= 0.000017
# True
# Iter 1100: Loss= 0.000016
# True
# Iter 1101: Loss= 0.000016
# True
# Iter 1102: Loss= 0.000016
# True
# Iter 1103: Loss= 0.000015
# True
# Iter 1104: Loss= 0.000015
# True
# Iter 1105: Loss= 0.000015
# True
# Iter 1106: Loss= 0.000014
# True
# Iter 1107: Loss= 0.000014
# True
# Iter 1108: Loss= 0.000014
# True
# Iter 1109: Loss= 0.000014
# True
# Iter 1110: Loss= 0.000013
# True
# Iter 1111: Loss= 0.000013
# True
# Iter 1112: Loss= 0.000013
# True
# Iter 1113: Loss= 0.000012
# True
# Iter 1114: Loss= 0.000012
# True
# Iter 1115: Loss= 0.000012
# True
# Iter 1116: Loss= 0.000012
# True
# Iter 1117: Loss= 0.000011
# True
# Iter 1118: Loss= 0.000011
# True
# Iter 1119: Loss= 0.000011
# True
# Iter 1120: Loss= 0.000011
# True
# Iter 1121: Loss= 0.000010
# True
# Iter 1122: Loss= 0.000010
# True
# Iter 1123: Loss= 0.000010
# True
# Iter 1124: Loss= 0.000010
# True
# Iter 1125: Loss= 0.000009
# True
# Iter 1126: Loss= 0.000009
# True
# Iter 1127: Loss= 0.000009
# True
# Iter 1128: Loss= 0.000009
# True
# Iter 1129: Loss= 0.000009
# True
# Iter 1130: Loss= 0.000009
# True
# Iter 1131: Loss= 0.000008
# True
# Iter 1132: Loss= 0.000008
# True
# Iter 1133: Loss= 0.000008
# True
# Iter 1134: Loss= 0.000008
# True
# Iter 1135: Loss= 0.000008
# True
# Iter 1136: Loss= 0.000008
# True
# Iter 1137: Loss= 0.000007
# True
# Iter 1138: Loss= 0.000007
# True
# Iter 1139: Loss= 0.000007
# True
# Iter 1140: Loss= 0.000007
# True
# Iter 1141: Loss= 0.000007
# True
# Iter 1142: Loss= 0.000007
# True
# Iter 1143: Loss= 0.000006
# True
# Iter 1144: Loss= 0.000006
# True
# Iter 1145: Loss= 0.000006
# True
# Iter 1146: Loss= 0.000006
# True
# Iter 1147: Loss= 0.000006
# True
# Iter 1148: Loss= 0.000006
# True
# Iter 1149: Loss= 0.000005
# True
# Iter 1150: Loss= 0.000005
# True
# Iter 1151: Loss= 0.000005
# True
# Iter 1152: Loss= 0.000005
# True
# Iter 1153: Loss= 0.000005
# True
# Iter 1154: Loss= 0.000005
# True
# Iter 1155: Loss= 0.000005
# True
# Iter 1156: Loss= 0.000005
# True
# Iter 1157: Loss= 0.000005
# True
# Iter 1158: Loss= 0.000004
# True
# Iter 1159: Loss= 0.000004
# True
# Iter 1160: Loss= 0.000004
# True
# Iter 1161: Loss= 0.000004
# True
# Iter 1162: Loss= 0.000004
# True
# Iter 1163: Loss= 0.000004
# True
# Iter 1164: Loss= 0.000004
# True
# Iter 1165: Loss= 0.000004
# True
# Iter 1166: Loss= 0.000003
# True
# Iter 1167: Loss= 0.000003
# True
# Iter 1168: Loss= 0.000003
# True
# Iter 1169: Loss= 0.000003
# True
# Iter 1170: Loss= 0.000003
# True
# Iter 1171: Loss= 0.000003
# True
# Iter 1172: Loss= 0.000003
# True
# Iter 1173: Loss= 0.000003
# True
# Iter 1174: Loss= 0.000003
# True
# Iter 1175: Loss= 0.000003
# True
# Iter 1176: Loss= 0.000003
# True
# Iter 1177: Loss= 0.000002
# True
# Iter 1178: Loss= 0.000002
# True
# Iter 1179: Loss= 0.000002
# True
# Iter 1180: Loss= 0.000002
# True
# Iter 1181: Loss= 0.000002
# True
# Iter 1182: Loss= 0.000002
# True
# Iter 1183: Loss= 0.000002
# True
# Iter 1184: Loss= 0.000002
# True
# Iter 1185: Loss= 0.000002
# True
# Iter 1186: Loss= 0.000002
# True
# Iter 1187: Loss= 0.000002
# True
# Iter 1188: Loss= 0.000002
# True
# Iter 1189: Loss= 0.000002
# True
# Iter 1190: Loss= 0.000002
# True
# Iter 1191: Loss= 0.000002
# True
# Iter 1192: Loss= 0.000002
# True
# Iter 1193: Loss= 0.000002
# True
# Iter 1194: Loss= 0.000001
# True
# Iter 1195: Loss= 0.000001
# True
# Iter 1196: Loss= 0.000001
# True
# Iter 1197: Loss= 0.000001
# True
# Iter 1198: Loss= 0.000001
# True
# Iter 1199: Loss= 0.000001
# True
# Iter 1200: Loss= 0.000001
# True
# Iter 1201: Loss= 0.000001
# True
# Iter 1202: Loss= 0.000001
# True
# Iter 1203: Loss= 0.000001
# True
# Iter 1204: Loss= 0.000001
# True
# Iter 1205: Loss= 0.000001
# True
# Iter 1206: Loss= 0.000001
# True
# Iter 1207: Loss= 0.000001
# True
# Iter 1208: Loss= 0.000001
# True
# Iter 1209: Loss= 0.000001
# True
# Iter 1210: Loss= 0.000001
# True
# Iter 1211: Loss= 0.000001
# True
# Iter 1212: Loss= 0.000001
# True
# Iter 1213: Loss= 0.000001
# True
# Iter 1214: Loss= 0.000001
# True
# Iter 1215: Loss= 0.000001
# True
# Iter 1216: Loss= 0.000001
# True
# Iter 1217: Loss= 0.000001
# True
# Iter 1218: Loss= 0.000001
# True
# Iter 1219: Loss= 0.000001
# True
# Iter 1220: Loss= 0.000000
# True
# Iter 1221: Loss= 0.000000
# True
# Iter 1222: Loss= 0.000000
# True
# Iter 1223: Loss= 0.000000
# True
# Iter 1224: Loss= 0.000000
# True
# Iter 1225: Loss= 0.000000
# True
# Iter 1226: Loss= 0.000000
# True
# Iter 1227: Loss= 0.000000
# True
# Iter 1228: Loss= 0.000000
# True
# Iter 1229: Loss= 0.000000
# True
# Iter 1230: Loss= 0.000000
# True
# Iter 1231: Loss= 0.000000
# True
# Iter 1232: Loss= 0.000000
# True
# Iter 1233: Loss= 0.000000
# True
# Iter 1234: Loss= 0.000000
# True
# Iter 1235: Loss= 0.000000
# True
# Iter 1236: Loss= 0.000000
# True
# Iter 1237: Loss= 0.000000
# True
# Iter 1238: Loss= 0.000000
# True
# Iter 1239: Loss= 0.000000
# True
# Iter 1240: Loss= 0.000000
# True
# Iter 1241: Loss= 0.000000
# True
# Iter 1242: Loss= 0.000000
# True
# Iter 1243: Loss= 0.000000
# True
# Iter 1244: Loss= 0.000000
# True
# Iter 1245: Loss= 0.000000
# True
# Iter 1246: Loss= 0.000000
# True
# Iter 1247: Loss= 0.000000
# True
# Iter 1248: Loss= 0.000000
# True
# Iter 1249: Loss= 0.000000
# True
# Iter 1250: Loss= 0.000000
# True
# Iter 1251: Loss= 0.000000
# True
# Iter 1252: Loss= 0.000000
# True
# Iter 1253: Loss= 0.000000
# True
# Iter 1254: Loss= 0.000000
# True
# Iter 1255: Loss= 0.000000
# True
# Iter 1256: Loss= 0.000000
# True
# Iter 1257: Loss= 0.000000
# True
# Iter 1258: Loss= 0.000000
# True
# Iter 1259: Loss= 0.000000
# True
# Iter 1260: Loss= 0.000000
# True
# Iter 1261: Loss= 0.000000
# True
# Iter 1262: Loss= 0.000000
# True
# Iter 1263: Loss= 0.000000
# True
# Iter 1264: Loss= 0.000000
# True
# Iter 1265: Loss= 0.000000
# True
# Iter 1266: Loss= 0.000000
# True
# Iter 1267: Loss= 0.000000
# True
# Iter 1268: Loss= 0.000000
# True
# Iter 1269: Loss= 0.000000
# True
# Iter 1270: Loss= 0.000000
# True
# Iter 1271: Loss= 0.000000
# True
# Iter 1272: Loss= 0.000000
# True
# Iter 1273: Loss= 0.000000
# True
# Iter 1274: Loss= 0.000000
# True
# Iter 1275: Loss= 0.000000
# True
# Iter 1276: Loss= 0.000000
# True
# Iter 1277: Loss= 0.000000
# True
# Iter 1278: Loss= 0.000000
# True
# Iter 1279: Loss= 0.000000
# True
# Iter 1280: Loss= 0.000000
# True
# Iter 1281: Loss= 0.000000
# True
# Iter 1282: Loss= 0.000000
# True
# Iter 1283: Loss= 0.000000
# True
# Iter 1284: Loss= 0.000000
# True
# Iter 1285: Loss= 0.000000
# True
# Iter 1286: Loss= 0.000000
# True
# Iter 1287: Loss= 0.000000
# True
# Iter 1288: Loss= 0.000000
# True
# Iter 1289: Loss= 0.000000
# True
# Iter 1290: Loss= 0.000000
# True
# Iter 1291: Loss= 0.000000
# True
# Iter 1292: Loss= 0.000000
# True
# Iter 1293: Loss= 0.000000
# True
# Iter 1294: Loss= 0.000000
# True
# Iter 1295: Loss= 0.000000
# True
# Iter 1296: Loss= 0.000000
# True
# Iter 1297: Loss= 0.000000
# True
# Iter 1298: Loss= 0.000000
# True
# Iter 1299: Loss= 0.000000
# True
# Iter 1300: Loss= 0.000000
# True
# Iter 1301: Loss= 0.000000
# True
# Iter 1302: Loss= 0.000000
# True
# Iter 1303: Loss= 0.000000
# True
# Iter 1304: Loss= 0.000000
# True
# Iter 1305: Loss= 0.000000
# True
# Iter 1306: Loss= 0.000000
# True
# Iter 1307: Loss= 0.000000
# True
# Iter 1308: Loss= 0.000000
# True
# Iter 1309: Loss= 0.000000
# True
# Iter 1310: Loss= 0.000000
# True
# Iter 1311: Loss= 0.000000
# True
# Iter 1312: Loss= 0.000000
# True
# Iter 1313: Loss= 0.000000
# True
# Iter 1314: Loss= 0.000000
# True
# Iter 1315: Loss= 0.000000
# True
# Iter 1316: Loss= 0.000000
# True
# Iter 1317: Loss= 0.000000
# True
# Iter 1318: Loss= 0.000000
# True
# Iter 1319: Loss= 0.000000
# True
# Iter 1320: Loss= 0.000000
# True
# Iter 1321: Loss= 0.000000
# Optimization Finished!
# tensor([[ 9.9999e-01,  3.0000e+00,  1.0000e+00, -1.0596e-05],
#         [ 2.0000e+00,  4.0000e+00, -2.5000e+00,  1.5000e+00],
#         [-4.7110e-06, -1.2038e-06, -2.0000e+00,  9.9998e-01],
#         [ 1.0384e-05,  1.5830e-05,  1.5000e+00, -4.9998e-01]],
#        grad_fn=<MmBackward>)

# %% [markdown]
# ##Comparison between Vanilla and MiniBatch

# %%
x_0_300 = np.arange(0,300)
plt.plot(losses_1[0:300], 'r', label="Vanilla")
plt.plot(batch_losses[0:300], 'b', label='MiniBatch')

plt.xlabel('epochs')
plt.ylabel('loss')

plt.legend()
plt.show()

# %%
x_1000_1200 = np.arange(1000,1200)
plt.plot(x_1000_1200,batch_losses[1000:1200], 'b', label='MiniBatch 32')

plt.xlabel('epochs')
plt.ylabel('loss')

plt.legend()
plt.show()
